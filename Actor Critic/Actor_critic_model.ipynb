# %%
import os
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import tensorflow_probability as tfp
import gym
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class ActorCriticNetwork(keras.Model):
  def __init__(self, n_actions, fc1_dims=1024, fc2_dims=512, name='actor_critic', chkpt_dir = '/content/tmp'):
    super(ActorCriticNetwork, self).__init__()
    self.fc1_dims = fc1_dims
    self.fc2_dims = fc2_dims
    self.n_actions = n_actions
    self.model_name = name
    self.checkpoint_dir = chkpt_dir
    self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_ac')

    self.fc1 = Dense(self.fc1_dims, activation='relu')
    self.fc2 = Dense(self.fc2_dims, activation='relu')
    self.v = Dense(1, activation = None)
    self.pi = Dense(n_actions, activation = 'softmax')

  def call(self, state):
    value = self.fc1(state)
    value = self.fc2(value)

    v = self.v(value)
    pi = self.pi(value)

    return v, pi

# %%
class Agent:
  def __init__(self, alpha=0.0003, gamma=0.99, n_actions=2):
    # super(ActorCriticNetwork, self).__init__(type(n_actions))
    self.gamma = gamma
    self.n_actions = n_actions
    self.action = None
    self.action_space = [i for i in range(self.n_actions)]

    self.actor_critic = ActorCriticNetwork(n_actions=n_actions)

    self.actor_critic.compile(optimizer=Adam(learning_rate=alpha))

  def choose_action(self, observation):
    state = tf.convert_to_tensor([observation])
    _, probs = self.actor_critic(state)

    action_probabilities = tfp.distributions.Categorical(probs=probs)
    action = action_probabilities.sample()
    self.action = action

    return action.numpy()[0]

  def save_model(self):
    print('....saving model.....')
    self.actor_critic.save_weights(self.actor_critic.checkpoint_file)

  def load_model(self):
    print('.....loading models.....')
    self.actor_critic.load_weights(self.actor_critic.checkpoint_file)

  def learn(self, state, reward, state_, done):
    state = tf.convert_to_tensor([state], dtype=tf.float32)
    state_ = tf.convert_to_tensor([state_], dtype=tf.float32)
    reward = tf.convert_to_tensor(reward, dtype=tf.float32)

    with tf.GradientTape() as tape:
      state_value, probs = self.actor_critic(state)
      state_value_, _ = self.actor_critic(state_)
      state_value = tf.squeeze(state_value)
      state_value_ = tf.squeeze(state_value_)

      action_probs = tfp.distributions.Categorical(probs=probs)
      log_probs = action_probs.log_prob(self.action)

      delta = reward + self.gamma*state_value_*(1-int(done)) - state_value
      actor_loss = log_probs*delta
      critic_loss = delta**2

      total_loss = actor_loss + critic_loss

    gradient = tape.gradient(total_loss, self.actor_critic.trainable_variables)
    self.actor_critic.optimizer.apply_gradients(zip(gradient, self.actor_critic.trainable_variables))

# %%
if __name__ == '__main__':
  env = gym.make('CartPole-v1')
  agent = Agent(alpha=1e-7, n_actions = env.action_space.n)
  n_games=1800

  filename = 'cartpole.png'

  best_score = env.reward_range[0]
  score_history = []
  load_checkpoint = False

  if load_checkpoint:
    agent.load_model()

  for i in range(n_games):
    observation = env.reset()
    done = False
    score = 0
    while not done:
      action = agent.choose_action(observation)
      observation_, reward, done, info = env.step(action)
      score += reward
      if not load_checkpoint:
        agent.learn(observation, reward, observation_, done)
      observation = observation_
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])

    if avg_score > best_score:
      best_score = avg_score
      if not load_checkpoint:
        agent.save_model()

    print('episode ', i, 'score %.1f' % score, 'avg_score %.1f' %avg_score)

  x = [i for i in range(n_games)]
  plt.plot(x, score_history)
# Out:
# ....saving model.....
# episode  0 score 18.0 avg_score 18.0
# episode  1 score 18.0 avg_score 18.0
# episode  2 score 9.0 avg_score 15.0
# ....saving model.....
# episode  3 score 34.0 avg_score 19.8
# episode  4 score 15.0 avg_score 18.8
# ....saving model.....
# episode  5 score 25.0 avg_score 19.8
# ....saving model.....
# episode  6 score 32.0 avg_score 21.6
# episode  7 score 17.0 avg_score 21.0
# episode  8 score 17.0 avg_score 20.6
# episode  9 score 21.0 avg_score 20.6
# episode  10 score 26.0 avg_score 21.1
# episode  11 score 15.0 avg_score 20.6
# episode  12 score 15.0 avg_score 20.2
# episode  13 score 19.0 avg_score 20.1
# episode  14 score 16.0 avg_score 19.8
# episode  15 score 15.0 avg_score 19.5
# episode  16 score 10.0 avg_score 18.9
# episode  17 score 13.0 avg_score 18.6
# episode  18 score 18.0 avg_score 18.6
# episode  19 score 29.0 avg_score 19.1
# episode  20 score 14.0 avg_score 18.9
# episode  21 score 20.0 avg_score 18.9
# episode  22 score 17.0 avg_score 18.8
# episode  23 score 30.0 avg_score 19.3
# episode  24 score 11.0 avg_score 19.0
# episode  25 score 28.0 avg_score 19.3
# episode  26 score 13.0 avg_score 19.1
# episode  27 score 11.0 avg_score 18.8
# episode  28 score 11.0 avg_score 18.5
# episode  29 score 13.0 avg_score 18.3
# episode  30 score 10.0 avg_score 18.1
# episode  31 score 35.0 avg_score 18.6
# episode  32 score 16.0 avg_score 18.5
# episode  33 score 19.0 avg_score 18.5
# episode  34 score 22.0 avg_score 18.6
# episode  35 score 32.0 avg_score 19.0
# episode  36 score 18.0 avg_score 19.0
# episode  37 score 22.0 avg_score 19.1
# episode  38 score 34.0 avg_score 19.4
# episode  39 score 24.0 avg_score 19.6
# episode  40 score 17.0 avg_score 19.5
# episode  41 score 17.0 avg_score 19.4
# episode  42 score 51.0 avg_score 20.2
# episode  43 score 30.0 avg_score 20.4
# episode  44 score 17.0 avg_score 20.3
# episode  45 score 15.0 avg_score 20.2
# episode  46 score 17.0 avg_score 20.1
# episode  47 score 56.0 avg_score 20.9
# episode  48 score 40.0 avg_score 21.3
# episode  49 score 15.0 avg_score 21.1
# episode  50 score 13.0 avg_score 21.0
# episode  51 score 15.0 avg_score 20.9
# episode  52 score 9.0 avg_score 20.6
# episode  53 score 13.0 avg_score 20.5
# episode  54 score 43.0 avg_score 20.9
# episode  55 score 44.0 avg_score 21.3
# episode  56 score 11.0 avg_score 21.1
# episode  57 score 11.0 avg_score 21.0
# episode  58 score 38.0 avg_score 21.3
# episode  59 score 10.0 avg_score 21.1
# episode  60 score 20.0 avg_score 21.0
# episode  61 score 31.0 avg_score 21.2
# episode  62 score 31.0 avg_score 21.4
# episode  63 score 16.0 avg_score 21.3
# episode  64 score 31.0 avg_score 21.4
# episode  65 score 26.0 avg_score 21.5
# episode  66 score 19.0 avg_score 21.5
# episode  67 score 11.0 avg_score 21.3
# episode  68 score 11.0 avg_score 21.2
# episode  69 score 22.0 avg_score 21.2
# episode  70 score 25.0 avg_score 21.2
# episode  71 score 14.0 avg_score 21.1
# episode  72 score 16.0 avg_score 21.1
# episode  73 score 11.0 avg_score 20.9
# episode  74 score 32.0 avg_score 21.1
# episode  75 score 13.0 avg_score 21.0
# episode  76 score 24.0 avg_score 21.0
# episode  77 score 24.0 avg_score 21.0
# episode  78 score 11.0 avg_score 20.9
# episode  79 score 25.0 avg_score 21.0
# episode  80 score 18.0 avg_score 20.9
# episode  81 score 24.0 avg_score 21.0
# episode  82 score 14.0 avg_score 20.9
# episode  83 score 10.0 avg_score 20.8
# episode  84 score 11.0 avg_score 20.6
# episode  85 score 24.0 avg_score 20.7
# episode  86 score 27.0 avg_score 20.7
# episode  87 score 36.0 avg_score 20.9
# episode  88 score 11.0 avg_score 20.8
# episode  89 score 24.0 avg_score 20.8
# episode  90 score 16.0 avg_score 20.8
# episode  91 score 9.0 avg_score 20.7
# episode  92 score 13.0 avg_score 20.6
# episode  93 score 12.0 avg_score 20.5
# episode  94 score 19.0 avg_score 20.5
# episode  95 score 30.0 avg_score 20.6
# episode  96 score 25.0 avg_score 20.6
# episode  97 score 19.0 avg_score 20.6
# episode  98 score 13.0 avg_score 20.5
# episode  99 score 14.0 avg_score 20.5
# episode  100 score 20.0 avg_score 20.5
# episode  101 score 23.0 avg_score 20.5
# episode  102 score 34.0 avg_score 20.8
# episode  103 score 12.0 avg_score 20.6
# episode  104 score 13.0 avg_score 20.5
# episode  105 score 16.0 avg_score 20.4
# episode  106 score 34.0 avg_score 20.5
# episode  107 score 26.0 avg_score 20.6
# episode  108 score 46.0 avg_score 20.9
# episode  109 score 14.0 avg_score 20.8
# episode  110 score 21.0 avg_score 20.7
# episode  111 score 26.0 avg_score 20.8
# episode  112 score 16.0 avg_score 20.9
# episode  113 score 25.0 avg_score 20.9
# episode  114 score 20.0 avg_score 20.9
# episode  115 score 46.0 avg_score 21.3
# episode  116 score 11.0 avg_score 21.3
# episode  117 score 14.0 avg_score 21.3
# episode  118 score 10.0 avg_score 21.2
# episode  119 score 10.0 avg_score 21.0
# ....saving model.....
# episode  120 score 95.0 avg_score 21.8
# episode  121 score 18.0 avg_score 21.8
# episode  122 score 12.0 avg_score 21.8
# episode  123 score 37.0 avg_score 21.8
# ....saving model.....
# episode  124 score 14.0 avg_score 21.9
# episode  125 score 12.0 avg_score 21.7
# episode  126 score 11.0 avg_score 21.7
# episode  127 score 14.0 avg_score 21.7
# episode  128 score 23.0 avg_score 21.8
# episode  129 score 15.0 avg_score 21.8
# ....saving model.....
# episode  130 score 28.0 avg_score 22.0
# episode  131 score 18.0 avg_score 21.9
# episode  132 score 14.0 avg_score 21.8
# episode  133 score 16.0 avg_score 21.8
# episode  134 score 27.0 avg_score 21.9
# episode  135 score 23.0 avg_score 21.8
# episode  136 score 20.0 avg_score 21.8
# episode  137 score 19.0 avg_score 21.8
# episode  138 score 23.0 avg_score 21.6
# episode  139 score 20.0 avg_score 21.6
# episode  140 score 19.0 avg_score 21.6
# episode  141 score 12.0 avg_score 21.6
# episode  142 score 13.0 avg_score 21.2
# episode  143 score 20.0 avg_score 21.1
# episode  144 score 74.0 avg_score 21.7
# episode  145 score 11.0 avg_score 21.6
# episode  146 score 15.0 avg_score 21.6
# episode  147 score 28.0 avg_score 21.3
# episode  148 score 28.0 avg_score 21.2
# episode  149 score 10.0 avg_score 21.1
# episode  150 score 31.0 avg_score 21.3
# episode  151 score 20.0 avg_score 21.4
# episode  152 score 19.0 avg_score 21.5
# episode  153 score 41.0 avg_score 21.8
# episode  154 score 29.0 avg_score 21.6
# episode  155 score 11.0 avg_score 21.3
# episode  156 score 29.0 avg_score 21.5
# episode  157 score 16.0 avg_score 21.5
# episode  158 score 25.0 avg_score 21.4
# episode  159 score 10.0 avg_score 21.4
# episode  160 score 15.0 avg_score 21.3
# episode  161 score 23.0 avg_score 21.3
# episode  162 score 12.0 avg_score 21.1
# episode  163 score 17.0 avg_score 21.1
# episode  164 score 29.0 avg_score 21.1
# episode  165 score 21.0 avg_score 21.0
# episode  166 score 17.0 avg_score 21.0
# episode  167 score 30.0 avg_score 21.2
# episode  168 score 25.0 avg_score 21.3
# episode  169 score 11.0 avg_score 21.2
# episode  170 score 21.0 avg_score 21.2
# episode  171 score 13.0 avg_score 21.2
# ....saving model.....
# episode  172 score 105.0 avg_score 22.1
# ....saving model.....
# episode  173 score 28.0 avg_score 22.2
# episode  174 score 13.0 avg_score 22.0
# episode  175 score 14.0 avg_score 22.0
# episode  176 score 16.0 avg_score 22.0
# episode  177 score 12.0 avg_score 21.8
# episode  178 score 39.0 avg_score 22.1
# episode  179 score 22.0 avg_score 22.1
# episode  180 score 17.0 avg_score 22.1
# episode  181 score 33.0 avg_score 22.2
# ....saving model.....
# episode  182 score 34.0 avg_score 22.4
# episode  183 score 9.0 avg_score 22.4
# episode  184 score 10.0 avg_score 22.4
# ....saving model.....
# episode  185 score 43.0 avg_score 22.5
# episode  186 score 20.0 avg_score 22.5
# episode  187 score 28.0 avg_score 22.4
# ....saving model.....
# episode  188 score 35.0 avg_score 22.6
# episode  189 score 24.0 avg_score 22.6
# ....saving model.....
# episode  190 score 26.0 avg_score 22.7
# ....saving model.....
# episode  191 score 18.0 avg_score 22.8
# ....saving model.....
# episode  192 score 18.0 avg_score 22.9
# ....saving model.....
# episode  193 score 15.0 avg_score 22.9
# ....saving model.....
# episode  194 score 26.0 avg_score 23.0
# episode  195 score 12.0 avg_score 22.8
# episode  196 score 25.0 avg_score 22.8
# ....saving model.....
# episode  197 score 45.0 avg_score 23.1
# episode  198 score 11.0 avg_score 23.0
# episode  199 score 14.0 avg_score 23.0
# episode  200 score 19.0 avg_score 23.0
# episode  201 score 17.0 avg_score 23.0
# episode  202 score 27.0 avg_score 22.9
# episode  203 score 26.0 avg_score 23.0
# ....saving model.....
# episode  204 score 26.0 avg_score 23.2
# ....saving model.....
# episode  205 score 20.0 avg_score 23.2
# episode  206 score 21.0 avg_score 23.1
# episode  207 score 23.0 avg_score 23.0
# episode  208 score 9.0 avg_score 22.7
# episode  209 score 20.0 avg_score 22.7
# episode  210 score 18.0 avg_score 22.7
# episode  211 score 17.0 avg_score 22.6
# episode  212 score 12.0 avg_score 22.6
# episode  213 score 19.0 avg_score 22.5
# episode  214 score 13.0 avg_score 22.4
# episode  215 score 24.0 avg_score 22.2
# episode  216 score 37.0 avg_score 22.5
# episode  217 score 39.0 avg_score 22.7
# episode  218 score 9.0 avg_score 22.7
# episode  219 score 26.0 avg_score 22.9
# episode  220 score 19.0 avg_score 22.1
# episode  221 score 34.0 avg_score 22.3
# episode  222 score 14.0 avg_score 22.3
# episode  223 score 27.0 avg_score 22.2
# episode  224 score 16.0 avg_score 22.2
# episode  225 score 56.0 avg_score 22.7
# episode  226 score 62.0 avg_score 23.2
# ....saving model.....
# episode  227 score 26.0 avg_score 23.3
# episode  228 score 16.0 avg_score 23.2
# episode  229 score 10.0 avg_score 23.2
# episode  230 score 19.0 avg_score 23.1
# episode  231 score 20.0 avg_score 23.1
# episode  232 score 9.0 avg_score 23.1
# episode  233 score 26.0 avg_score 23.1
# episode  234 score 39.0 avg_score 23.3
# ....saving model.....
# episode  235 score 35.0 avg_score 23.4
# episode  236 score 11.0 avg_score 23.3
# episode  237 score 12.0 avg_score 23.2
# episode  238 score 12.0 avg_score 23.1
# episode  239 score 11.0 avg_score 23.0
# episode  240 score 12.0 avg_score 23.0
# episode  241 score 17.0 avg_score 23.0
# episode  242 score 11.0 avg_score 23.0
# episode  243 score 21.0 avg_score 23.0
# episode  244 score 13.0 avg_score 22.4
# episode  245 score 25.0 avg_score 22.5
# episode  246 score 74.0 avg_score 23.1
# episode  247 score 15.0 avg_score 23.0
# episode  248 score 18.0 avg_score 22.9
# episode  249 score 15.0 avg_score 22.9
# episode  250 score 21.0 avg_score 22.8
# episode  251 score 11.0 avg_score 22.8
# episode  252 score 10.0 avg_score 22.7
# episode  253 score 36.0 avg_score 22.6
# episode  254 score 18.0 avg_score 22.5
# episode  255 score 11.0 avg_score 22.5
# episode  256 score 20.0 avg_score 22.4
# episode  257 score 31.0 avg_score 22.6
# episode  258 score 15.0 avg_score 22.5
# episode  259 score 21.0 avg_score 22.6
# episode  260 score 14.0 avg_score 22.6
# episode  261 score 14.0 avg_score 22.5
# episode  262 score 22.0 avg_score 22.6
# episode  263 score 9.0 avg_score 22.5
# episode  264 score 17.0 avg_score 22.4
# episode  265 score 22.0 avg_score 22.4
# episode  266 score 18.0 avg_score 22.4
# episode  267 score 30.0 avg_score 22.4
# episode  268 score 34.0 avg_score 22.5
# episode  269 score 35.0 avg_score 22.7
# episode  270 score 16.0 avg_score 22.7
# episode  271 score 42.0 avg_score 23.0
# episode  272 score 12.0 avg_score 22.0
# episode  273 score 19.0 avg_score 21.9
# episode  274 score 27.0 avg_score 22.1
# episode  275 score 21.0 avg_score 22.1
# episode  276 score 27.0 avg_score 22.3
# episode  277 score 25.0 avg_score 22.4
# episode  278 score 17.0 avg_score 22.2
# episode  279 score 15.0 avg_score 22.1
# episode  280 score 30.0 avg_score 22.2
# episode  281 score 14.0 avg_score 22.0
# episode  282 score 16.0 avg_score 21.9
# episode  283 score 11.0 avg_score 21.9
# episode  284 score 23.0 avg_score 22.0
# episode  285 score 16.0 avg_score 21.7
# episode  286 score 15.0 avg_score 21.7
# episode  287 score 19.0 avg_score 21.6
# episode  288 score 60.0 avg_score 21.9
# episode  289 score 35.0 avg_score 22.0
# episode  290 score 17.0 avg_score 21.9
# episode  291 score 17.0 avg_score 21.9
# episode  292 score 22.0 avg_score 21.9
# episode  293 score 31.0 avg_score 22.1
# episode  294 score 27.0 avg_score 22.1
# episode  295 score 12.0 avg_score 22.1
# episode  296 score 13.0 avg_score 21.9
# episode  297 score 15.0 avg_score 21.6
# episode  298 score 17.0 avg_score 21.7
# episode  299 score 14.0 avg_score 21.7
# episode  300 score 44.0 avg_score 22.0
# episode  301 score 32.0 avg_score 22.1
# episode  302 score 45.0 avg_score 22.3
# episode  303 score 22.0 avg_score 22.2
# episode  304 score 13.0 avg_score 22.1
# episode  305 score 19.0 avg_score 22.1
# episode  306 score 27.0 avg_score 22.2
# episode  307 score 26.0 avg_score 22.2
# episode  308 score 50.0 avg_score 22.6
# episode  309 score 13.0 avg_score 22.5
# episode  310 score 12.0 avg_score 22.5
# episode  311 score 15.0 avg_score 22.5
# episode  312 score 17.0 avg_score 22.5
# episode  313 score 12.0 avg_score 22.4
# episode  314 score 17.0 avg_score 22.5
# episode  315 score 17.0 avg_score 22.4
# episode  316 score 15.0 avg_score 22.2
# episode  317 score 28.0 avg_score 22.1
# episode  318 score 14.0 avg_score 22.1
# episode  319 score 15.0 avg_score 22.0
# episode  320 score 89.0 avg_score 22.7
# episode  321 score 22.0 avg_score 22.6
# episode  322 score 19.0 avg_score 22.6
# episode  323 score 15.0 avg_score 22.5
# episode  324 score 16.0 avg_score 22.5
# episode  325 score 14.0 avg_score 22.1
# episode  326 score 23.0 avg_score 21.7
# episode  327 score 19.0 avg_score 21.6
# episode  328 score 13.0 avg_score 21.6
# episode  329 score 20.0 avg_score 21.7
# episode  330 score 57.0 avg_score 22.1
# episode  331 score 14.0 avg_score 22.0
# episode  332 score 29.0 avg_score 22.2
# episode  333 score 26.0 avg_score 22.2
# episode  334 score 12.0 avg_score 22.0
# episode  335 score 25.0 avg_score 21.9
# episode  336 score 19.0 avg_score 21.9
# episode  337 score 21.0 avg_score 22.0
# episode  338 score 29.0 avg_score 22.2
# episode  339 score 10.0 avg_score 22.2
# episode  340 score 28.0 avg_score 22.4
# episode  341 score 18.0 avg_score 22.4
# episode  342 score 11.0 avg_score 22.4
# episode  343 score 36.0 avg_score 22.5
# episode  344 score 17.0 avg_score 22.6
# episode  345 score 10.0 avg_score 22.4
# episode  346 score 11.0 avg_score 21.8
# episode  347 score 13.0 avg_score 21.8
# episode  348 score 10.0 avg_score 21.7
# episode  349 score 17.0 avg_score 21.7
# episode  350 score 29.0 avg_score 21.8
# episode  351 score 24.0 avg_score 21.9
# episode  352 score 23.0 avg_score 22.0
# episode  353 score 21.0 avg_score 21.9
# episode  354 score 13.0 avg_score 21.8
# episode  355 score 43.0 avg_score 22.2
# episode  356 score 19.0 avg_score 22.1
# episode  357 score 31.0 avg_score 22.1
# episode  358 score 9.0 avg_score 22.1
# episode  359 score 27.0 avg_score 22.1
# episode  360 score 11.0 avg_score 22.1
# episode  361 score 21.0 avg_score 22.2
# episode  362 score 12.0 avg_score 22.1
# episode  363 score 22.0 avg_score 22.2
# episode  364 score 10.0 avg_score 22.1
# episode  365 score 12.0 avg_score 22.1
# episode  366 score 20.0 avg_score 22.1
# episode  367 score 24.0 avg_score 22.0
# episode  368 score 17.0 avg_score 21.8
# episode  369 score 18.0 avg_score 21.7
# episode  370 score 15.0 avg_score 21.7
# episode  371 score 16.0 avg_score 21.4
# episode  372 score 28.0 avg_score 21.6
# episode  373 score 17.0 avg_score 21.5
# episode  374 score 18.0 avg_score 21.4
# episode  375 score 12.0 avg_score 21.4
# episode  376 score 27.0 avg_score 21.4
# episode  377 score 15.0 avg_score 21.3
# episode  378 score 22.0 avg_score 21.3
# episode  379 score 22.0 avg_score 21.4
# episode  380 score 17.0 avg_score 21.2
# episode  381 score 18.0 avg_score 21.3
# episode  382 score 15.0 avg_score 21.3
# episode  383 score 15.0 avg_score 21.3
# episode  384 score 18.0 avg_score 21.3
# episode  385 score 12.0 avg_score 21.2
# episode  386 score 21.0 avg_score 21.3
# episode  387 score 20.0 avg_score 21.3
# episode  388 score 24.0 avg_score 20.9
# episode  389 score 20.0 avg_score 20.8
# episode  390 score 27.0 avg_score 20.9
# episode  391 score 23.0 avg_score 20.9
# episode  392 score 29.0 avg_score 21.0
# episode  393 score 18.0 avg_score 20.9
# episode  394 score 13.0 avg_score 20.8
# episode  395 score 28.0 avg_score 20.9
# episode  396 score 27.0 avg_score 21.1
# episode  397 score 36.0 avg_score 21.3
# episode  398 score 15.0 avg_score 21.2
# episode  399 score 12.0 avg_score 21.2
# episode  400 score 10.0 avg_score 20.9
# episode  401 score 10.0 avg_score 20.7
# episode  402 score 12.0 avg_score 20.3
# episode  403 score 23.0 avg_score 20.3
# episode  404 score 44.0 avg_score 20.6
# episode  405 score 53.0 avg_score 21.0
# episode  406 score 19.0 avg_score 20.9
# episode  407 score 16.0 avg_score 20.8
# episode  408 score 9.0 avg_score 20.4
# episode  409 score 27.0 avg_score 20.5
# episode  410 score 31.0 avg_score 20.7
# episode  411 score 14.0 avg_score 20.7
# episode  412 score 22.0 avg_score 20.8
# episode  413 score 14.0 avg_score 20.8
# episode  414 score 17.0 avg_score 20.8
# episode  415 score 20.0 avg_score 20.8
# episode  416 score 20.0 avg_score 20.9
# episode  417 score 16.0 avg_score 20.8
# episode  418 score 41.0 avg_score 21.0
# episode  419 score 71.0 avg_score 21.6
# episode  420 score 34.0 avg_score 21.0
# episode  421 score 35.0 avg_score 21.2
# episode  422 score 37.0 avg_score 21.3
# episode  423 score 18.0 avg_score 21.4
# episode  424 score 11.0 avg_score 21.3
# episode  425 score 13.0 avg_score 21.3
# episode  426 score 23.0 avg_score 21.3
# episode  427 score 29.0 avg_score 21.4
# episode  428 score 13.0 avg_score 21.4
# episode  429 score 13.0 avg_score 21.3
# episode  430 score 92.0 avg_score 21.7
# episode  431 score 21.0 avg_score 21.8
# episode  432 score 23.0 avg_score 21.7
# episode  433 score 43.0 avg_score 21.9
# episode  434 score 17.0 avg_score 21.9
# episode  435 score 36.0 avg_score 22.0
# episode  436 score 14.0 avg_score 22.0
# episode  437 score 9.0 avg_score 21.9
# episode  438 score 27.0 avg_score 21.8
# episode  439 score 24.0 avg_score 22.0
# episode  440 score 12.0 avg_score 21.8
# episode  441 score 36.0 avg_score 22.0
# episode  442 score 8.0 avg_score 22.0
# episode  443 score 10.0 avg_score 21.7
# episode  444 score 35.0 avg_score 21.9
# episode  445 score 19.0 avg_score 22.0
# episode  446 score 12.0 avg_score 22.0
# episode  447 score 17.0 avg_score 22.0
# episode  448 score 13.0 avg_score 22.1
# episode  449 score 25.0 avg_score 22.1
# episode  450 score 49.0 avg_score 22.3
# episode  451 score 38.0 avg_score 22.5
# episode  452 score 16.0 avg_score 22.4
# episode  453 score 22.0 avg_score 22.4
# episode  454 score 17.0 avg_score 22.5
# episode  455 score 24.0 avg_score 22.3
# episode  456 score 11.0 avg_score 22.2
# episode  457 score 17.0 avg_score 22.1
# episode  458 score 13.0 avg_score 22.1
# episode  459 score 28.0 avg_score 22.1
# episode  460 score 28.0 avg_score 22.3
# episode  461 score 25.0 avg_score 22.3
# episode  462 score 10.0 avg_score 22.3
# episode  463 score 16.0 avg_score 22.2
# episode  464 score 13.0 avg_score 22.3
# episode  465 score 19.0 avg_score 22.3
# episode  466 score 11.0 avg_score 22.2
# episode  467 score 9.0 avg_score 22.1
# episode  468 score 30.0 avg_score 22.2
# episode  469 score 10.0 avg_score 22.1
# episode  470 score 10.0 avg_score 22.1
# episode  471 score 22.0 avg_score 22.1
# episode  472 score 12.0 avg_score 22.0
# episode  473 score 10.0 avg_score 21.9
# episode  474 score 15.0 avg_score 21.9
# episode  475 score 25.0 avg_score 22.0
# episode  476 score 30.0 avg_score 22.1
# episode  477 score 19.0 avg_score 22.1
# episode  478 score 14.0 avg_score 22.0
# episode  479 score 16.0 avg_score 21.9
# episode  480 score 12.0 avg_score 21.9
# episode  481 score 10.0 avg_score 21.8
# episode  482 score 13.0 avg_score 21.8
# episode  483 score 21.0 avg_score 21.9
# episode  484 score 17.0 avg_score 21.9
# episode  485 score 15.0 avg_score 21.9
# episode  486 score 16.0 avg_score 21.8
# episode  487 score 17.0 avg_score 21.8
# episode  488 score 15.0 avg_score 21.7
# episode  489 score 15.0 avg_score 21.7
# episode  490 score 15.0 avg_score 21.5
# episode  491 score 21.0 avg_score 21.5
# episode  492 score 16.0 avg_score 21.4
# episode  493 score 32.0 avg_score 21.5
# episode  494 score 11.0 avg_score 21.5
# episode  495 score 24.0 avg_score 21.5
# episode  496 score 10.0 avg_score 21.3
# episode  497 score 35.0 avg_score 21.3
# episode  498 score 16.0 avg_score 21.3
# episode  499 score 13.0 avg_score 21.3
# episode  500 score 11.0 avg_score 21.3
# episode  501 score 12.0 avg_score 21.3
# episode  502 score 9.0 avg_score 21.3
# episode  503 score 21.0 avg_score 21.3
# episode  504 score 21.0 avg_score 21.1
# episode  505 score 18.0 avg_score 20.7
# episode  506 score 24.0 avg_score 20.8
# episode  507 score 9.0 avg_score 20.7
# episode  508 score 19.0 avg_score 20.8
# episode  509 score 18.0 avg_score 20.7
# episode  510 score 18.0 avg_score 20.6
# episode  511 score 18.0 avg_score 20.6
# episode  512 score 38.0 avg_score 20.8
# episode  513 score 14.0 avg_score 20.8
# episode  514 score 15.0 avg_score 20.8
# episode  515 score 57.0 avg_score 21.1
# episode  516 score 15.0 avg_score 21.1
# episode  517 score 12.0 avg_score 21.0
# episode  518 score 32.0 avg_score 20.9
# episode  519 score 15.0 avg_score 20.4
# episode  520 score 9.0 avg_score 20.1
# episode  521 score 30.0 avg_score 20.1
# episode  522 score 24.0 avg_score 19.9
# episode  523 score 37.0 avg_score 20.1
# episode  524 score 13.0 avg_score 20.2
# episode  525 score 19.0 avg_score 20.2
# episode  526 score 21.0 avg_score 20.2
# episode  527 score 15.0 avg_score 20.1
# episode  528 score 14.0 avg_score 20.1
# episode  529 score 84.0 avg_score 20.8
# episode  530 score 32.0 avg_score 20.2
# episode  531 score 10.0 avg_score 20.1
# episode  532 score 17.0 avg_score 20.0
# episode  533 score 20.0 avg_score 19.8
# episode  534 score 9.0 avg_score 19.7
# episode  535 score 19.0 avg_score 19.5
# episode  536 score 20.0 avg_score 19.6
# episode  537 score 22.0 avg_score 19.7
# episode  538 score 23.0 avg_score 19.7
# episode  539 score 15.0 avg_score 19.6
# episode  540 score 54.0 avg_score 20.0
# episode  541 score 33.0 avg_score 20.0
# episode  542 score 18.0 avg_score 20.1
# episode  543 score 11.0 avg_score 20.1
# episode  544 score 19.0 avg_score 19.9
# episode  545 score 34.0 avg_score 20.1
# episode  546 score 20.0 avg_score 20.2
# episode  547 score 15.0 avg_score 20.1
# episode  548 score 40.0 avg_score 20.4
# episode  549 score 22.0 avg_score 20.4
# episode  550 score 25.0 avg_score 20.1
# episode  551 score 28.0 avg_score 20.0
# episode  552 score 11.0 avg_score 20.0
# episode  553 score 11.0 avg_score 19.9
# episode  554 score 9.0 avg_score 19.8
# episode  555 score 14.0 avg_score 19.7
# episode  556 score 16.0 avg_score 19.8
# episode  557 score 14.0 avg_score 19.7
# episode  558 score 24.0 avg_score 19.8
# episode  559 score 12.0 avg_score 19.7
# episode  560 score 22.0 avg_score 19.6
# episode  561 score 33.0 avg_score 19.7
# episode  562 score 28.0 avg_score 19.9
# episode  563 score 14.0 avg_score 19.9
# episode  564 score 11.0 avg_score 19.8
# episode  565 score 22.0 avg_score 19.9
# episode  566 score 50.0 avg_score 20.2
# episode  567 score 30.0 avg_score 20.5
# episode  568 score 10.0 avg_score 20.3
# episode  569 score 18.0 avg_score 20.3
# episode  570 score 15.0 avg_score 20.4
# episode  571 score 26.0 avg_score 20.4
# episode  572 score 14.0 avg_score 20.4
# episode  573 score 17.0 avg_score 20.5
# episode  574 score 33.0 avg_score 20.7
# episode  575 score 33.0 avg_score 20.8
# episode  576 score 12.0 avg_score 20.6
# episode  577 score 11.0 avg_score 20.5
# episode  578 score 16.0 avg_score 20.5
# episode  579 score 15.0 avg_score 20.5
# episode  580 score 27.0 avg_score 20.7
# episode  581 score 43.0 avg_score 21.0
# episode  582 score 30.0 avg_score 21.2
# episode  583 score 25.0 avg_score 21.2
# episode  584 score 10.0 avg_score 21.1
# episode  585 score 13.0 avg_score 21.1
# episode  586 score 19.0 avg_score 21.2
# episode  587 score 43.0 avg_score 21.4
# episode  588 score 36.0 avg_score 21.6
# episode  589 score 45.0 avg_score 21.9
# episode  590 score 17.0 avg_score 21.9
# episode  591 score 15.0 avg_score 21.9
# episode  592 score 14.0 avg_score 21.9
# episode  593 score 34.0 avg_score 21.9
# episode  594 score 19.0 avg_score 22.0
# episode  595 score 22.0 avg_score 21.9
# episode  596 score 34.0 avg_score 22.2
# episode  597 score 41.0 avg_score 22.2
# episode  598 score 14.0 avg_score 22.2
# episode  599 score 10.0 avg_score 22.2
# episode  600 score 16.0 avg_score 22.2
# episode  601 score 9.0 avg_score 22.2
# episode  602 score 18.0 avg_score 22.3
# episode  603 score 16.0 avg_score 22.3
# episode  604 score 22.0 avg_score 22.3
# episode  605 score 16.0 avg_score 22.2
# episode  606 score 29.0 avg_score 22.3
# episode  607 score 14.0 avg_score 22.4
# episode  608 score 62.0 avg_score 22.8
# episode  609 score 12.0 avg_score 22.7
# episode  610 score 25.0 avg_score 22.8
# episode  611 score 15.0 avg_score 22.8
# episode  612 score 14.0 avg_score 22.5
# episode  613 score 48.0 avg_score 22.9
# episode  614 score 15.0 avg_score 22.9
# episode  615 score 27.0 avg_score 22.6
# episode  616 score 12.0 avg_score 22.5
# episode  617 score 18.0 avg_score 22.6
# episode  618 score 16.0 avg_score 22.4
# episode  619 score 22.0 avg_score 22.5
# episode  620 score 12.0 avg_score 22.5
# episode  621 score 17.0 avg_score 22.4
# episode  622 score 10.0 avg_score 22.3
# episode  623 score 20.0 avg_score 22.1
# episode  624 score 19.0 avg_score 22.1
# episode  625 score 17.0 avg_score 22.1
# episode  626 score 16.0 avg_score 22.1
# episode  627 score 28.0 avg_score 22.2
# episode  628 score 24.0 avg_score 22.3
# episode  629 score 27.0 avg_score 21.7
# episode  630 score 10.0 avg_score 21.5
# episode  631 score 52.0 avg_score 21.9
# episode  632 score 27.0 avg_score 22.0
# episode  633 score 16.0 avg_score 22.0
# episode  634 score 25.0 avg_score 22.2
# episode  635 score 46.0 avg_score 22.4
# episode  636 score 13.0 avg_score 22.4
# episode  637 score 19.0 avg_score 22.3
# episode  638 score 14.0 avg_score 22.2
# episode  639 score 13.0 avg_score 22.2
# episode  640 score 26.0 avg_score 21.9
# episode  641 score 13.0 avg_score 21.7
# episode  642 score 30.0 avg_score 21.9
# episode  643 score 19.0 avg_score 21.9
# episode  644 score 16.0 avg_score 21.9
# episode  645 score 13.0 avg_score 21.7
# episode  646 score 21.0 avg_score 21.7
# episode  647 score 41.0 avg_score 22.0
# episode  648 score 18.0 avg_score 21.8
# episode  649 score 22.0 avg_score 21.8
# episode  650 score 16.0 avg_score 21.7
# episode  651 score 13.0 avg_score 21.5
# episode  652 score 12.0 avg_score 21.5
# episode  653 score 27.0 avg_score 21.7
# episode  654 score 32.0 avg_score 21.9
# episode  655 score 16.0 avg_score 21.9
# episode  656 score 25.0 avg_score 22.0
# episode  657 score 10.0 avg_score 22.0
# episode  658 score 11.0 avg_score 21.9
# episode  659 score 55.0 avg_score 22.3
# episode  660 score 12.0 avg_score 22.2
# episode  661 score 18.0 avg_score 22.0
# episode  662 score 45.0 avg_score 22.2
# episode  663 score 51.0 avg_score 22.6
# episode  664 score 14.0 avg_score 22.6
# episode  665 score 18.0 avg_score 22.6
# episode  666 score 17.0 avg_score 22.2
# episode  667 score 18.0 avg_score 22.1
# episode  668 score 15.0 avg_score 22.2
# episode  669 score 14.0 avg_score 22.1
# episode  670 score 16.0 avg_score 22.1
# episode  671 score 21.0 avg_score 22.1
# episode  672 score 15.0 avg_score 22.1
# episode  673 score 30.0 avg_score 22.2
# episode  674 score 12.0 avg_score 22.0
# episode  675 score 12.0 avg_score 21.8
# episode  676 score 9.0 avg_score 21.8
# episode  677 score 22.0 avg_score 21.9
# episode  678 score 15.0 avg_score 21.9
# episode  679 score 17.0 avg_score 21.9
# episode  680 score 19.0 avg_score 21.8
# episode  681 score 16.0 avg_score 21.5
# episode  682 score 12.0 avg_score 21.4
# episode  683 score 20.0 avg_score 21.3
# episode  684 score 18.0 avg_score 21.4
# episode  685 score 24.0 avg_score 21.5
# episode  686 score 45.0 avg_score 21.8
# episode  687 score 40.0 avg_score 21.7
# episode  688 score 13.0 avg_score 21.5
# episode  689 score 12.0 avg_score 21.2
# episode  690 score 27.0 avg_score 21.3
# episode  691 score 22.0 avg_score 21.3
# episode  692 score 10.0 avg_score 21.3
# episode  693 score 17.0 avg_score 21.1
# episode  694 score 17.0 avg_score 21.1
# episode  695 score 10.0 avg_score 21.0
# episode  696 score 28.0 avg_score 20.9
# episode  697 score 20.0 avg_score 20.7
# episode  698 score 13.0 avg_score 20.7
# episode  699 score 29.0 avg_score 20.9
# episode  700 score 17.0 avg_score 20.9
# episode  701 score 20.0 avg_score 21.0
# episode  702 score 20.0 avg_score 21.0
# episode  703 score 20.0 avg_score 21.1
# episode  704 score 15.0 avg_score 21.0
# episode  705 score 13.0 avg_score 21.0
# episode  706 score 17.0 avg_score 20.9
# episode  707 score 29.0 avg_score 21.0
# episode  708 score 24.0 avg_score 20.6
# episode  709 score 18.0 avg_score 20.7
# episode  710 score 15.0 avg_score 20.6
# episode  711 score 30.0 avg_score 20.7
# episode  712 score 15.0 avg_score 20.8
# episode  713 score 14.0 avg_score 20.4
# episode  714 score 13.0 avg_score 20.4
# episode  715 score 12.0 avg_score 20.2
# episode  716 score 13.0 avg_score 20.2
# episode  717 score 10.0 avg_score 20.2
# episode  718 score 33.0 avg_score 20.3
# episode  719 score 45.0 avg_score 20.6
# episode  720 score 38.0 avg_score 20.8
# episode  721 score 18.0 avg_score 20.8
# episode  722 score 35.0 avg_score 21.1
# episode  723 score 14.0 avg_score 21.0
# episode  724 score 9.0 avg_score 20.9
# episode  725 score 40.0 avg_score 21.2
# episode  726 score 25.0 avg_score 21.2
# episode  727 score 14.0 avg_score 21.1
# episode  728 score 26.0 avg_score 21.1
# episode  729 score 18.0 avg_score 21.0
# episode  730 score 28.0 avg_score 21.2
# episode  731 score 13.0 avg_score 20.8
# episode  732 score 31.0 avg_score 20.9
# episode  733 score 10.0 avg_score 20.8
# episode  734 score 50.0 avg_score 21.1
# episode  735 score 26.0 avg_score 20.9
# episode  736 score 14.0 avg_score 20.9
# episode  737 score 22.0 avg_score 20.9
# episode  738 score 60.0 avg_score 21.4
# episode  739 score 19.0 avg_score 21.4
# episode  740 score 15.0 avg_score 21.3
# episode  741 score 17.0 avg_score 21.4
# episode  742 score 12.0 avg_score 21.2
# episode  743 score 12.0 avg_score 21.1
# episode  744 score 17.0 avg_score 21.1
# episode  745 score 10.0 avg_score 21.1
# episode  746 score 14.0 avg_score 21.0
# episode  747 score 19.0 avg_score 20.8
# episode  748 score 18.0 avg_score 20.8
# episode  749 score 12.0 avg_score 20.7
# episode  750 score 43.0 avg_score 21.0
# episode  751 score 39.0 avg_score 21.2
# episode  752 score 18.0 avg_score 21.3
# episode  753 score 25.0 avg_score 21.3
# episode  754 score 34.0 avg_score 21.3
# episode  755 score 27.0 avg_score 21.4
# episode  756 score 12.0 avg_score 21.3
# episode  757 score 13.0 avg_score 21.3
# episode  758 score 23.0 avg_score 21.4
# episode  759 score 25.0 avg_score 21.1
# episode  760 score 36.0 avg_score 21.4
# episode  761 score 26.0 avg_score 21.4
# episode  762 score 18.0 avg_score 21.2
# episode  763 score 23.0 avg_score 20.9
# episode  764 score 28.0 avg_score 21.0
# episode  765 score 26.0 avg_score 21.1
# episode  766 score 45.0 avg_score 21.4
# episode  767 score 26.0 avg_score 21.5
# episode  768 score 19.0 avg_score 21.5
# episode  769 score 23.0 avg_score 21.6
# episode  770 score 28.0 avg_score 21.7
# episode  771 score 26.0 avg_score 21.8
# episode  772 score 21.0 avg_score 21.8
# episode  773 score 17.0 avg_score 21.7
# episode  774 score 15.0 avg_score 21.7
# episode  775 score 30.0 avg_score 21.9
# episode  776 score 26.0 avg_score 22.1
# episode  777 score 16.0 avg_score 22.0
# episode  778 score 12.0 avg_score 22.0
# episode  779 score 21.0 avg_score 22.0
# episode  780 score 16.0 avg_score 22.0
# episode  781 score 14.0 avg_score 22.0
# episode  782 score 21.0 avg_score 22.1
# episode  783 score 13.0 avg_score 22.0
# episode  784 score 11.0 avg_score 21.9
# episode  785 score 26.0 avg_score 21.9
# episode  786 score 14.0 avg_score 21.6
# episode  787 score 17.0 avg_score 21.4
# episode  788 score 21.0 avg_score 21.5
# episode  789 score 13.0 avg_score 21.5
# episode  790 score 26.0 avg_score 21.5
# episode  791 score 9.0 avg_score 21.4
# episode  792 score 18.0 avg_score 21.4
# episode  793 score 28.0 avg_score 21.5
# episode  794 score 14.0 avg_score 21.5
# episode  795 score 19.0 avg_score 21.6
# episode  796 score 40.0 avg_score 21.7
# episode  797 score 26.0 avg_score 21.8
# episode  798 score 14.0 avg_score 21.8
# episode  799 score 18.0 avg_score 21.7
# episode  800 score 14.0 avg_score 21.6
# episode  801 score 20.0 avg_score 21.6
# episode  802 score 12.0 avg_score 21.6
# episode  803 score 22.0 avg_score 21.6
# episode  804 score 18.0 avg_score 21.6
# episode  805 score 15.0 avg_score 21.6
# episode  806 score 19.0 avg_score 21.7
# episode  807 score 21.0 avg_score 21.6
# episode  808 score 26.0 avg_score 21.6
# episode  809 score 14.0 avg_score 21.6
# episode  810 score 9.0 avg_score 21.5
# episode  811 score 20.0 avg_score 21.4
# episode  812 score 11.0 avg_score 21.4
# episode  813 score 14.0 avg_score 21.4
# episode  814 score 10.0 avg_score 21.3
# episode  815 score 22.0 avg_score 21.4
# episode  816 score 10.0 avg_score 21.4
# episode  817 score 14.0 avg_score 21.4
# episode  818 score 12.0 avg_score 21.2
# episode  819 score 10.0 avg_score 20.9
# episode  820 score 21.0 avg_score 20.7
# episode  821 score 9.0 avg_score 20.6
# episode  822 score 40.0 avg_score 20.7
# episode  823 score 20.0 avg_score 20.7
# episode  824 score 24.0 avg_score 20.9
# episode  825 score 33.0 avg_score 20.8
# episode  826 score 29.0 avg_score 20.9
# episode  827 score 13.0 avg_score 20.8
# episode  828 score 19.0 avg_score 20.8
# episode  829 score 10.0 avg_score 20.7
# episode  830 score 18.0 avg_score 20.6
# episode  831 score 24.0 avg_score 20.7
# episode  832 score 15.0 avg_score 20.5
# episode  833 score 46.0 avg_score 20.9
# episode  834 score 20.0 avg_score 20.6
# episode  835 score 18.0 avg_score 20.5
# episode  836 score 24.0 avg_score 20.6
# episode  837 score 31.0 avg_score 20.7
# episode  838 score 11.0 avg_score 20.2
# episode  839 score 26.0 avg_score 20.3
# episode  840 score 12.0 avg_score 20.3
# episode  841 score 15.0 avg_score 20.2
# episode  842 score 13.0 avg_score 20.2
# episode  843 score 10.0 avg_score 20.2
# episode  844 score 19.0 avg_score 20.2
# episode  845 score 33.0 avg_score 20.5
# episode  846 score 18.0 avg_score 20.5
# episode  847 score 13.0 avg_score 20.5
# episode  848 score 14.0 avg_score 20.4
# episode  849 score 20.0 avg_score 20.5
# episode  850 score 16.0 avg_score 20.2
# episode  851 score 16.0 avg_score 20.0
# episode  852 score 36.0 avg_score 20.2
# episode  853 score 18.0 avg_score 20.1
# episode  854 score 9.0 avg_score 19.9
# episode  855 score 13.0 avg_score 19.7
# episode  856 score 16.0 avg_score 19.8
# episode  857 score 15.0 avg_score 19.8
# episode  858 score 22.0 avg_score 19.8
# episode  859 score 12.0 avg_score 19.6
# episode  860 score 11.0 avg_score 19.4
# episode  861 score 25.0 avg_score 19.4
# episode  862 score 19.0 avg_score 19.4
# episode  863 score 12.0 avg_score 19.3
# episode  864 score 12.0 avg_score 19.1
# episode  865 score 15.0 avg_score 19.0
# episode  866 score 86.0 avg_score 19.4
# episode  867 score 10.0 avg_score 19.3
# episode  868 score 16.0 avg_score 19.2
# episode  869 score 33.0 avg_score 19.3
# episode  870 score 16.0 avg_score 19.2
# episode  871 score 21.0 avg_score 19.2
# episode  872 score 10.0 avg_score 19.1
# episode  873 score 56.0 avg_score 19.4
# episode  874 score 12.0 avg_score 19.4
# episode  875 score 35.0 avg_score 19.5
# episode  876 score 23.0 avg_score 19.4
# episode  877 score 27.0 avg_score 19.5
# episode  878 score 39.0 avg_score 19.8
# episode  879 score 13.0 avg_score 19.7
# episode  880 score 18.0 avg_score 19.8
# episode  881 score 18.0 avg_score 19.8
# episode  882 score 19.0 avg_score 19.8
# episode  883 score 12.0 avg_score 19.8
# episode  884 score 15.0 avg_score 19.8
# episode  885 score 23.0 avg_score 19.8
# episode  886 score 24.0 avg_score 19.9
# episode  887 score 15.0 avg_score 19.9
# episode  888 score 15.0 avg_score 19.8
# episode  889 score 21.0 avg_score 19.9
# episode  890 score 26.0 avg_score 19.9
# episode  891 score 13.0 avg_score 19.9
# episode  892 score 19.0 avg_score 19.9
# episode  893 score 28.0 avg_score 19.9
# episode  894 score 29.0 avg_score 20.1
# episode  895 score 41.0 avg_score 20.3
# episode  896 score 22.0 avg_score 20.1
# episode  897 score 26.0 avg_score 20.1
# episode  898 score 20.0 avg_score 20.2
# episode  899 score 37.0 avg_score 20.4
# episode  900 score 11.0 avg_score 20.3
# episode  901 score 22.0 avg_score 20.4
# episode  902 score 18.0 avg_score 20.4
# episode  903 score 20.0 avg_score 20.4
# episode  904 score 43.0 avg_score 20.6
# episode  905 score 15.0 avg_score 20.6
# episode  906 score 15.0 avg_score 20.6
# episode  907 score 16.0 avg_score 20.6
# episode  908 score 20.0 avg_score 20.5
# episode  909 score 33.0 avg_score 20.7
# episode  910 score 27.0 avg_score 20.9
# episode  911 score 54.0 avg_score 21.2
# episode  912 score 13.0 avg_score 21.2
# episode  913 score 20.0 avg_score 21.3
# episode  914 score 10.0 avg_score 21.3
# episode  915 score 31.0 avg_score 21.4
# episode  916 score 52.0 avg_score 21.8
# episode  917 score 66.0 avg_score 22.3
# episode  918 score 20.0 avg_score 22.4
# episode  919 score 9.0 avg_score 22.4
# episode  920 score 21.0 avg_score 22.4
# episode  921 score 29.0 avg_score 22.6
# episode  922 score 15.0 avg_score 22.3
# episode  923 score 18.0 avg_score 22.3
# episode  924 score 15.0 avg_score 22.2
# episode  925 score 20.0 avg_score 22.1
# episode  926 score 27.0 avg_score 22.1
# episode  927 score 37.0 avg_score 22.3
# episode  928 score 22.0 avg_score 22.3
# episode  929 score 28.0 avg_score 22.5
# episode  930 score 27.0 avg_score 22.6
# episode  931 score 33.0 avg_score 22.7
# episode  932 score 15.0 avg_score 22.7
# episode  933 score 15.0 avg_score 22.4
# episode  934 score 16.0 avg_score 22.4
# episode  935 score 11.0 avg_score 22.3
# episode  936 score 14.0 avg_score 22.2
# episode  937 score 13.0 avg_score 22.0
# episode  938 score 17.0 avg_score 22.1
# episode  939 score 21.0 avg_score 22.0
# episode  940 score 11.0 avg_score 22.0
# episode  941 score 14.0 avg_score 22.0
# episode  942 score 23.0 avg_score 22.1
# episode  943 score 56.0 avg_score 22.6
# episode  944 score 16.0 avg_score 22.5
# episode  945 score 33.0 avg_score 22.5
# episode  946 score 26.0 avg_score 22.6
# episode  947 score 20.0 avg_score 22.7
# episode  948 score 12.0 avg_score 22.6
# episode  949 score 11.0 avg_score 22.6
# episode  950 score 15.0 avg_score 22.6
# episode  951 score 15.0 avg_score 22.5
# episode  952 score 12.0 avg_score 22.3
# episode  953 score 11.0 avg_score 22.2
# episode  954 score 63.0 avg_score 22.8
# episode  955 score 16.0 avg_score 22.8
# episode  956 score 24.0 avg_score 22.9
# episode  957 score 13.0 avg_score 22.9
# episode  958 score 20.0 avg_score 22.8
# episode  959 score 28.0 avg_score 23.0
# episode  960 score 24.0 avg_score 23.1
# episode  961 score 23.0 avg_score 23.1
# episode  962 score 23.0 avg_score 23.1
# episode  963 score 10.0 avg_score 23.1
# episode  964 score 29.0 avg_score 23.3
# episode  965 score 18.0 avg_score 23.3
# episode  966 score 31.0 avg_score 22.8
# episode  967 score 18.0 avg_score 22.9
# episode  968 score 9.0 avg_score 22.8
# episode  969 score 17.0 avg_score 22.6
# episode  970 score 12.0 avg_score 22.6
# episode  971 score 27.0 avg_score 22.6
# episode  972 score 11.0 avg_score 22.7
# episode  973 score 9.0 avg_score 22.2
# episode  974 score 41.0 avg_score 22.5
# episode  975 score 21.0 avg_score 22.3
# episode  976 score 17.0 avg_score 22.3
# episode  977 score 22.0 avg_score 22.2
# episode  978 score 16.0 avg_score 22.0
# episode  979 score 23.0 avg_score 22.1
# episode  980 score 62.0 avg_score 22.5
# episode  981 score 20.0 avg_score 22.6
# episode  982 score 28.0 avg_score 22.6
# episode  983 score 15.0 avg_score 22.7
# episode  984 score 25.0 avg_score 22.8
# episode  985 score 21.0 avg_score 22.8
# episode  986 score 59.0 avg_score 23.1
# episode  987 score 16.0 avg_score 23.1
# episode  988 score 26.0 avg_score 23.2
# episode  989 score 31.0 avg_score 23.3
# episode  990 score 17.0 avg_score 23.2
# episode  991 score 15.0 avg_score 23.3
# ....saving model.....
# episode  992 score 45.0 avg_score 23.5
# episode  993 score 26.0 avg_score 23.5
# episode  994 score 21.0 avg_score 23.4
# episode  995 score 40.0 avg_score 23.4
# ....saving model.....
# episode  996 score 40.0 avg_score 23.6
# episode  997 score 10.0 avg_score 23.4
# episode  998 score 23.0 avg_score 23.5
# episode  999 score 22.0 avg_score 23.3
# episode  1000 score 35.0 avg_score 23.6
# episode  1001 score 18.0 avg_score 23.5
# episode  1002 score 17.0 avg_score 23.5
# episode  1003 score 13.0 avg_score 23.4
# episode  1004 score 11.0 avg_score 23.1
# episode  1005 score 42.0 avg_score 23.4
# episode  1006 score 21.0 avg_score 23.4
# episode  1007 score 29.0 avg_score 23.6
# episode  1008 score 13.0 avg_score 23.5
# episode  1009 score 19.0 avg_score 23.4
# episode  1010 score 12.0 avg_score 23.2
# episode  1011 score 14.0 avg_score 22.8
# episode  1012 score 12.0 avg_score 22.8
# episode  1013 score 36.0 avg_score 23.0
# episode  1014 score 11.0 avg_score 23.0
# episode  1015 score 23.0 avg_score 22.9
# episode  1016 score 43.0 avg_score 22.8
# episode  1017 score 15.0 avg_score 22.3
# episode  1018 score 29.0 avg_score 22.4
# episode  1019 score 15.0 avg_score 22.4
# episode  1020 score 21.0 avg_score 22.4
# episode  1021 score 12.0 avg_score 22.3
# episode  1022 score 18.0 avg_score 22.3
# episode  1023 score 27.0 avg_score 22.4
# episode  1024 score 53.0 avg_score 22.8
# episode  1025 score 17.0 avg_score 22.7
# episode  1026 score 10.0 avg_score 22.6
# episode  1027 score 22.0 avg_score 22.4
# episode  1028 score 18.0 avg_score 22.4
# episode  1029 score 17.0 avg_score 22.3
# episode  1030 score 13.0 avg_score 22.1
# episode  1031 score 47.0 avg_score 22.3
# episode  1032 score 35.0 avg_score 22.5
# episode  1033 score 14.0 avg_score 22.5
# episode  1034 score 9.0 avg_score 22.4
# episode  1035 score 25.0 avg_score 22.5
# episode  1036 score 15.0 avg_score 22.5
# episode  1037 score 15.0 avg_score 22.6
# episode  1038 score 13.0 avg_score 22.5
# episode  1039 score 11.0 avg_score 22.4
# episode  1040 score 11.0 avg_score 22.4
# episode  1041 score 19.0 avg_score 22.5
# episode  1042 score 24.0 avg_score 22.5
# episode  1043 score 27.0 avg_score 22.2
# episode  1044 score 26.0 avg_score 22.3
# episode  1045 score 15.0 avg_score 22.1
# episode  1046 score 20.0 avg_score 22.1
# episode  1047 score 17.0 avg_score 22.0
# episode  1048 score 19.0 avg_score 22.1
# episode  1049 score 30.0 avg_score 22.3
# episode  1050 score 47.0 avg_score 22.6
# episode  1051 score 30.0 avg_score 22.8
# episode  1052 score 11.0 avg_score 22.7
# episode  1053 score 13.0 avg_score 22.8
# episode  1054 score 27.0 avg_score 22.4
# episode  1055 score 26.0 avg_score 22.5
# episode  1056 score 11.0 avg_score 22.4
# episode  1057 score 24.0 avg_score 22.5
# episode  1058 score 22.0 avg_score 22.5
# episode  1059 score 13.0 avg_score 22.4
# episode  1060 score 44.0 avg_score 22.6
# episode  1061 score 17.0 avg_score 22.5
# episode  1062 score 20.0 avg_score 22.5
# episode  1063 score 30.0 avg_score 22.7
# episode  1064 score 56.0 avg_score 22.9
# episode  1065 score 10.0 avg_score 22.9
# episode  1066 score 41.0 avg_score 22.9
# episode  1067 score 28.0 avg_score 23.1
# episode  1068 score 15.0 avg_score 23.1
# episode  1069 score 12.0 avg_score 23.1
# episode  1070 score 18.0 avg_score 23.1
# episode  1071 score 26.0 avg_score 23.1
# episode  1072 score 10.0 avg_score 23.1
# episode  1073 score 15.0 avg_score 23.2
# episode  1074 score 12.0 avg_score 22.9
# episode  1075 score 15.0 avg_score 22.8
# episode  1076 score 10.0 avg_score 22.7
# episode  1077 score 49.0 avg_score 23.0
# episode  1078 score 19.0 avg_score 23.0
# episode  1079 score 39.0 avg_score 23.2
# episode  1080 score 34.0 avg_score 22.9
# episode  1081 score 13.0 avg_score 22.9
# episode  1082 score 18.0 avg_score 22.8
# episode  1083 score 14.0 avg_score 22.7
# episode  1084 score 18.0 avg_score 22.7
# episode  1085 score 21.0 avg_score 22.7
# episode  1086 score 14.0 avg_score 22.2
# episode  1087 score 21.0 avg_score 22.3
# episode  1088 score 24.0 avg_score 22.2
# episode  1089 score 17.0 avg_score 22.1
# episode  1090 score 28.0 avg_score 22.2
# episode  1091 score 20.0 avg_score 22.3
# episode  1092 score 46.0 avg_score 22.3
# episode  1093 score 15.0 avg_score 22.2
# episode  1094 score 23.0 avg_score 22.2
# episode  1095 score 19.0 avg_score 22.0
# episode  1096 score 17.0 avg_score 21.8
# episode  1097 score 11.0 avg_score 21.8
# episode  1098 score 36.0 avg_score 21.9
# episode  1099 score 12.0 avg_score 21.8
# episode  1100 score 13.0 avg_score 21.6
# episode  1101 score 11.0 avg_score 21.5
# episode  1102 score 26.0 avg_score 21.6
# episode  1103 score 19.0 avg_score 21.6
# episode  1104 score 16.0 avg_score 21.7
# episode  1105 score 13.0 avg_score 21.4
# episode  1106 score 23.0 avg_score 21.4
# episode  1107 score 27.0 avg_score 21.4
# episode  1108 score 23.0 avg_score 21.5
# episode  1109 score 14.0 avg_score 21.5
# episode  1110 score 18.0 avg_score 21.5
# episode  1111 score 12.0 avg_score 21.5
# episode  1112 score 10.0 avg_score 21.5
# episode  1113 score 9.0 avg_score 21.2
# episode  1114 score 14.0 avg_score 21.2
# episode  1115 score 24.0 avg_score 21.2
# episode  1116 score 19.0 avg_score 21.0
# episode  1117 score 15.0 avg_score 21.0
# episode  1118 score 12.0 avg_score 20.8
# episode  1119 score 19.0 avg_score 20.9
# episode  1120 score 16.0 avg_score 20.8
# episode  1121 score 17.0 avg_score 20.9
# episode  1122 score 21.0 avg_score 20.9
# episode  1123 score 11.0 avg_score 20.8
# episode  1124 score 20.0 avg_score 20.4
# episode  1125 score 31.0 avg_score 20.6
# episode  1126 score 23.0 avg_score 20.7
# episode  1127 score 31.0 avg_score 20.8
# episode  1128 score 25.0 avg_score 20.9
# episode  1129 score 24.0 avg_score 20.9
# episode  1130 score 12.0 avg_score 20.9
# episode  1131 score 42.0 avg_score 20.9
# episode  1132 score 77.0 avg_score 21.3
# episode  1133 score 16.0 avg_score 21.3
# episode  1134 score 35.0 avg_score 21.6
# episode  1135 score 23.0 avg_score 21.5
# episode  1136 score 24.0 avg_score 21.6
# episode  1137 score 12.0 avg_score 21.6
# episode  1138 score 21.0 avg_score 21.7
# episode  1139 score 27.0 avg_score 21.8
# episode  1140 score 17.0 avg_score 21.9
# episode  1141 score 14.0 avg_score 21.9
# episode  1142 score 19.0 avg_score 21.8
# episode  1143 score 21.0 avg_score 21.7
# episode  1144 score 32.0 avg_score 21.8
# episode  1145 score 21.0 avg_score 21.9
# episode  1146 score 16.0 avg_score 21.8
# episode  1147 score 16.0 avg_score 21.8
# episode  1148 score 10.0 avg_score 21.7
# episode  1149 score 9.0 avg_score 21.5
# episode  1150 score 28.0 avg_score 21.3
# episode  1151 score 26.0 avg_score 21.3
# episode  1152 score 39.0 avg_score 21.6
# episode  1153 score 32.0 avg_score 21.8
# episode  1154 score 24.0 avg_score 21.7
# episode  1155 score 21.0 avg_score 21.7
# episode  1156 score 18.0 avg_score 21.7
# episode  1157 score 21.0 avg_score 21.7
# episode  1158 score 17.0 avg_score 21.7
# episode  1159 score 25.0 avg_score 21.8
# episode  1160 score 29.0 avg_score 21.6
# episode  1161 score 23.0 avg_score 21.7
# episode  1162 score 15.0 avg_score 21.6
# episode  1163 score 14.0 avg_score 21.5
# episode  1164 score 11.0 avg_score 21.0
# episode  1165 score 21.0 avg_score 21.1
# episode  1166 score 9.0 avg_score 20.8
# episode  1167 score 14.0 avg_score 20.7
# episode  1168 score 21.0 avg_score 20.7
# episode  1169 score 13.0 avg_score 20.8
# episode  1170 score 33.0 avg_score 20.9
# episode  1171 score 17.0 avg_score 20.8
# episode  1172 score 15.0 avg_score 20.9
# episode  1173 score 33.0 avg_score 21.0
# episode  1174 score 16.0 avg_score 21.1
# episode  1175 score 11.0 avg_score 21.0
# episode  1176 score 13.0 avg_score 21.1
# episode  1177 score 26.0 avg_score 20.8
# episode  1178 score 11.0 avg_score 20.8
# episode  1179 score 15.0 avg_score 20.5
# episode  1180 score 11.0 avg_score 20.3
# episode  1181 score 26.0 avg_score 20.4
# episode  1182 score 20.0 avg_score 20.4
# episode  1183 score 14.0 avg_score 20.4
# episode  1184 score 13.0 avg_score 20.4
# episode  1185 score 9.0 avg_score 20.3
# episode  1186 score 25.0 avg_score 20.4
# episode  1187 score 25.0 avg_score 20.4
# episode  1188 score 15.0 avg_score 20.3
# episode  1189 score 14.0 avg_score 20.3
# episode  1190 score 28.0 avg_score 20.3
# episode  1191 score 24.0 avg_score 20.3
# episode  1192 score 15.0 avg_score 20.0
# episode  1193 score 10.0 avg_score 20.0
# episode  1194 score 20.0 avg_score 19.9
# episode  1195 score 15.0 avg_score 19.9
# episode  1196 score 29.0 avg_score 20.0
# episode  1197 score 34.0 avg_score 20.3
# episode  1198 score 23.0 avg_score 20.1
# episode  1199 score 12.0 avg_score 20.1
# episode  1200 score 15.0 avg_score 20.1
# episode  1201 score 27.0 avg_score 20.3
# episode  1202 score 13.0 avg_score 20.2
# episode  1203 score 13.0 avg_score 20.1
# episode  1204 score 12.0 avg_score 20.1
# episode  1205 score 12.0 avg_score 20.1
# episode  1206 score 32.0 avg_score 20.2
# episode  1207 score 21.0 avg_score 20.1
# episode  1208 score 17.0 avg_score 20.0
# episode  1209 score 31.0 avg_score 20.2
# episode  1210 score 45.0 avg_score 20.5
# episode  1211 score 28.0 avg_score 20.6
# episode  1212 score 43.0 avg_score 21.0
# episode  1213 score 14.0 avg_score 21.0
# episode  1214 score 47.0 avg_score 21.4
# ...
# episode  1402 score 31.0 avg_score 21.4
# episode  1403 score 16.0 avg_score 20.9
# episode  1404 score 18.0 avg_score 20.9
# episode  1405 score 11.0 avg_score 20.9
# episode  1406 score 37.0 avg_score 21.1
# episode  1407 score 9.0 avg_score 20.9
# episode  1408 score 24.0 avg_score 21.0
# episode  1409 score 37.0 avg_score 21.2
# episode  1410 score 16.0 avg_score 21.1
# episode  1411 score 23.0 avg_score 21.1
# episode  1412 score 15.0 avg_score 21.1
# episode  1413 score 9.0 avg_score 21.0
# episode  1414 score 14.0 avg_score 21.1
# episode  1415 score 16.0 avg_score 21.1
# episode  1416 score 40.0 avg_score 20.9
# episode  1417 score 19.0 avg_score 21.0
# episode  1418 score 17.0 avg_score 20.9
# episode  1419 score 12.0 avg_score 20.8
# episode  1420 score 18.0 avg_score 20.6
# episode  1421 score 30.0 avg_score 20.7
# episode  1422 score 26.0 avg_score 20.9
# episode  1423 score 17.0 avg_score 20.9
# episode  1424 score 10.0 avg_score 20.6
# episode  1425 score 21.0 avg_score 20.6
# episode  1426 score 13.0 avg_score 20.4
# episode  1427 score 13.0 avg_score 20.4
# episode  1428 score 28.0 avg_score 20.5
# episode  1429 score 24.0 avg_score 20.6
# episode  1430 score 31.0 avg_score 20.7
# episode  1431 score 16.0 avg_score 20.7
# episode  1432 score 24.0 avg_score 20.8
# episode  1433 score 18.0 avg_score 20.7
# episode  1434 score 17.0 avg_score 20.7
# episode  1435 score 55.0 avg_score 21.0
# episode  1436 score 51.0 avg_score 21.4
# episode  1437 score 51.0 avg_score 21.8
# episode  1438 score 14.0 avg_score 21.8
# episode  1439 score 14.0 avg_score 21.7
# episode  1440 score 11.0 avg_score 21.4
# episode  1441 score 13.0 avg_score 21.4
# episode  1442 score 19.0 avg_score 21.3
# episode  1443 score 16.0 avg_score 21.1
# episode  1444 score 14.0 avg_score 21.1
# episode  1445 score 22.0 avg_score 21.1
# episode  1446 score 30.0 avg_score 21.3
# episode  1447 score 26.0 avg_score 21.4
# episode  1448 score 20.0 avg_score 21.4
# episode  1449 score 21.0 avg_score 21.4
# episode  1450 score 31.0 avg_score 21.5
# episode  1451 score 27.0 avg_score 21.7
# episode  1452 score 29.0 avg_score 21.6
# episode  1453 score 42.0 avg_score 21.9
# episode  1454 score 21.0 avg_score 21.8
# episode  1455 score 18.0 avg_score 21.6
# episode  1456 score 14.0 avg_score 21.3
# episode  1457 score 27.0 avg_score 21.4
# episode  1458 score 13.0 avg_score 21.2
# episode  1459 score 24.0 avg_score 21.1
# episode  1460 score 14.0 avg_score 21.0
# episode  1461 score 15.0 avg_score 21.0
# episode  1462 score 38.0 avg_score 21.2
# episode  1463 score 26.0 avg_score 21.2
# episode  1464 score 35.0 avg_score 21.5
# episode  1465 score 37.0 avg_score 21.7
# episode  1466 score 10.0 avg_score 21.5
# episode  1467 score 27.0 avg_score 21.7
# episode  1468 score 12.0 avg_score 21.6
# episode  1469 score 29.0 avg_score 21.7
# episode  1470 score 24.0 avg_score 21.7
# episode  1471 score 20.0 avg_score 21.8
# episode  1472 score 18.0 avg_score 21.8
# episode  1473 score 32.0 avg_score 22.0
# episode  1474 score 42.0 avg_score 22.2
# episode  1475 score 23.0 avg_score 22.3
# episode  1476 score 37.0 avg_score 22.2
# episode  1477 score 12.0 avg_score 22.1
# episode  1478 score 15.0 avg_score 22.0
# episode  1479 score 26.0 avg_score 22.2
# episode  1480 score 37.0 avg_score 22.3
# episode  1481 score 11.0 avg_score 22.2
# episode  1482 score 23.0 avg_score 21.6
# episode  1483 score 13.0 avg_score 21.6
# episode  1484 score 27.0 avg_score 21.7
# episode  1485 score 11.0 avg_score 21.7
# episode  1486 score 12.0 avg_score 21.6
# episode  1487 score 20.0 avg_score 21.5
# episode  1488 score 32.0 avg_score 21.7
# episode  1489 score 18.0 avg_score 21.6
# episode  1490 score 42.0 avg_score 21.9
# episode  1491 score 18.0 avg_score 21.9
# episode  1492 score 38.0 avg_score 22.1
# episode  1493 score 22.0 avg_score 22.2
# episode  1494 score 15.0 avg_score 22.3
# episode  1495 score 15.0 avg_score 22.3
# episode  1496 score 13.0 avg_score 22.2
# episode  1497 score 17.0 avg_score 22.3
# episode  1498 score 22.0 avg_score 22.4
# episode  1499 score 23.0 avg_score 22.5
# episode  1500 score 12.0 avg_score 22.4
# episode  1501 score 11.0 avg_score 22.4
# episode  1502 score 18.0 avg_score 22.2
# episode  1503 score 29.0 avg_score 22.4
# episode  1504 score 37.0 avg_score 22.6
# episode  1505 score 21.0 avg_score 22.7
# episode  1506 score 32.0 avg_score 22.6
# episode  1507 score 23.0 avg_score 22.8
# episode  1508 score 28.0 avg_score 22.8
# episode  1509 score 30.0 avg_score 22.7
# episode  1510 score 17.0 avg_score 22.7
# episode  1511 score 41.0 avg_score 22.9
# episode  1512 score 19.0 avg_score 22.9
# episode  1513 score 11.0 avg_score 23.0
# episode  1514 score 12.0 avg_score 22.9
# episode  1515 score 23.0 avg_score 23.0
# episode  1516 score 30.0 avg_score 22.9
# episode  1517 score 14.0 avg_score 22.9
# episode  1518 score 9.0 avg_score 22.8
# episode  1519 score 19.0 avg_score 22.9
# episode  1520 score 18.0 avg_score 22.9
# episode  1521 score 12.0 avg_score 22.7
# episode  1522 score 25.0 avg_score 22.7
# episode  1523 score 24.0 avg_score 22.7
# episode  1524 score 28.0 avg_score 22.9
# episode  1525 score 42.0 avg_score 23.1
# episode  1526 score 50.0 avg_score 23.5
# episode  1527 score 9.0 avg_score 23.5
# episode  1528 score 14.0 avg_score 23.3
# episode  1529 score 13.0 avg_score 23.2
# episode  1530 score 11.0 avg_score 23.0
# episode  1531 score 32.0 avg_score 23.2
# episode  1532 score 29.0 avg_score 23.2
# episode  1533 score 21.0 avg_score 23.2
# episode  1534 score 21.0 avg_score 23.3
# episode  1535 score 39.0 avg_score 23.1
# episode  1536 score 15.0 avg_score 22.8
# episode  1537 score 38.0 avg_score 22.6
# episode  1538 score 26.0 avg_score 22.8
# episode  1539 score 10.0 avg_score 22.7
# episode  1540 score 16.0 avg_score 22.8
# episode  1541 score 37.0 avg_score 23.0
# episode  1542 score 11.0 avg_score 22.9
# episode  1543 score 12.0 avg_score 22.9
# episode  1544 score 43.0 avg_score 23.2
# episode  1545 score 32.0 avg_score 23.3
# episode  1546 score 21.0 avg_score 23.2
# episode  1547 score 19.0 avg_score 23.1
# episode  1548 score 45.0 avg_score 23.4
# episode  1549 score 21.0 avg_score 23.4
# episode  1550 score 16.0 avg_score 23.2
# episode  1551 score 21.0 avg_score 23.2
# episode  1552 score 23.0 avg_score 23.1
# episode  1553 score 58.0 avg_score 23.3
# episode  1554 score 39.0 avg_score 23.4
# ....saving model.....
# episode  1555 score 35.0 avg_score 23.6
# episode  1556 score 9.0 avg_score 23.6
# episode  1557 score 20.0 avg_score 23.5
# ....saving model.....
# episode  1558 score 30.0 avg_score 23.7
# ....saving model.....
# episode  1559 score 25.0 avg_score 23.7
# episode  1560 score 13.0 avg_score 23.7
# ....saving model.....
# episode  1561 score 36.0 avg_score 23.9
# episode  1562 score 16.0 avg_score 23.6
# episode  1563 score 28.0 avg_score 23.7
# episode  1564 score 10.0 avg_score 23.4
# episode  1565 score 14.0 avg_score 23.2
# episode  1566 score 11.0 avg_score 23.2
# episode  1567 score 34.0 avg_score 23.3
# episode  1568 score 17.0 avg_score 23.3
# episode  1569 score 10.0 avg_score 23.1
# episode  1570 score 16.0 avg_score 23.1
# episode  1571 score 19.0 avg_score 23.0
# episode  1572 score 26.0 avg_score 23.1
# episode  1573 score 14.0 avg_score 22.9
# episode  1574 score 35.0 avg_score 22.9
# episode  1575 score 29.0 avg_score 22.9
# episode  1576 score 12.0 avg_score 22.7
# episode  1577 score 22.0 avg_score 22.8
# episode  1578 score 16.0 avg_score 22.8
# episode  1579 score 19.0 avg_score 22.7
# episode  1580 score 15.0 avg_score 22.5
# episode  1581 score 22.0 avg_score 22.6
# episode  1582 score 11.0 avg_score 22.5
# episode  1583 score 68.0 avg_score 23.0
# episode  1584 score 13.0 avg_score 22.9
# episode  1585 score 33.0 avg_score 23.1
# episode  1586 score 18.0 avg_score 23.2
# episode  1587 score 16.0 avg_score 23.1
# episode  1588 score 16.0 avg_score 23.0
# episode  1589 score 9.0 avg_score 22.9
# episode  1590 score 16.0 avg_score 22.6
# episode  1591 score 15.0 avg_score 22.6
# episode  1592 score 17.0 avg_score 22.4
# episode  1593 score 12.0 avg_score 22.3
# episode  1594 score 33.0 avg_score 22.5
# episode  1595 score 44.0 avg_score 22.8
# episode  1596 score 16.0 avg_score 22.8
# episode  1597 score 25.0 avg_score 22.9
# episode  1598 score 23.0 avg_score 22.9
# episode  1599 score 9.0 avg_score 22.7
# episode  1600 score 21.0 avg_score 22.8
# episode  1601 score 34.0 avg_score 23.1
# episode  1602 score 13.0 avg_score 23.0
# episode  1603 score 13.0 avg_score 22.9
# episode  1604 score 11.0 avg_score 22.6
# episode  1605 score 17.0 avg_score 22.6
# episode  1606 score 20.0 avg_score 22.4
# episode  1607 score 26.0 avg_score 22.5
# episode  1608 score 16.0 avg_score 22.3
# episode  1609 score 21.0 avg_score 22.2
# episode  1610 score 9.0 avg_score 22.2
# episode  1611 score 12.0 avg_score 21.9
# episode  1612 score 15.0 avg_score 21.8
# episode  1613 score 40.0 avg_score 22.1
# episode  1614 score 21.0 avg_score 22.2
# episode  1615 score 27.0 avg_score 22.3
# episode  1616 score 23.0 avg_score 22.2
# episode  1617 score 24.0 avg_score 22.3
# episode  1618 score 19.0 avg_score 22.4
# episode  1619 score 22.0 avg_score 22.4
# episode  1620 score 19.0 avg_score 22.4
# episode  1621 score 32.0 avg_score 22.6
# episode  1622 score 25.0 avg_score 22.6
# episode  1623 score 11.0 avg_score 22.5
# episode  1624 score 15.0 avg_score 22.4
# episode  1625 score 30.0 avg_score 22.2
# episode  1626 score 15.0 avg_score 21.9
# episode  1627 score 21.0 avg_score 22.0
# episode  1628 score 17.0 avg_score 22.1
# episode  1629 score 32.0 avg_score 22.2
# episode  1630 score 14.0 avg_score 22.3
# episode  1631 score 28.0 avg_score 22.2
# episode  1632 score 10.0 avg_score 22.0
# episode  1633 score 30.0 avg_score 22.1
# episode  1634 score 49.0 avg_score 22.4
# episode  1635 score 19.0 avg_score 22.2
# episode  1636 score 40.0 avg_score 22.5
# episode  1637 score 35.0 avg_score 22.4
# episode  1638 score 16.0 avg_score 22.3
# episode  1639 score 14.0 avg_score 22.4
# episode  1640 score 17.0 avg_score 22.4
# episode  1641 score 18.0 avg_score 22.2
# episode  1642 score 23.0 avg_score 22.3
# episode  1643 score 16.0 avg_score 22.4
# episode  1644 score 14.0 avg_score 22.1
# episode  1645 score 15.0 avg_score 21.9
# episode  1646 score 22.0 avg_score 21.9
# episode  1647 score 27.0 avg_score 22.0
# episode  1648 score 25.0 avg_score 21.8
# episode  1649 score 10.0 avg_score 21.7
# episode  1650 score 26.0 avg_score 21.8
# episode  1651 score 9.0 avg_score 21.6
# episode  1652 score 14.0 avg_score 21.6
# episode  1653 score 31.0 avg_score 21.3
# episode  1654 score 13.0 avg_score 21.0
# episode  1655 score 15.0 avg_score 20.8
# episode  1656 score 31.0 avg_score 21.1
# episode  1657 score 23.0 avg_score 21.1
# episode  1658 score 15.0 avg_score 20.9
# episode  1659 score 16.0 avg_score 20.8
# episode  1660 score 24.0 avg_score 20.9
# episode  1661 score 15.0 avg_score 20.7
# episode  1662 score 12.0 avg_score 20.7
# episode  1663 score 17.0 avg_score 20.6
# episode  1664 score 17.0 avg_score 20.7
# episode  1665 score 49.0 avg_score 21.0
# episode  1666 score 9.0 avg_score 21.0
# episode  1667 score 10.0 avg_score 20.8
# episode  1668 score 34.0 avg_score 20.9
# episode  1669 score 17.0 avg_score 21.0
# episode  1670 score 15.0 avg_score 21.0
# episode  1671 score 21.0 avg_score 21.0
# episode  1672 score 14.0 avg_score 20.9
# episode  1673 score 27.0 avg_score 21.0
# episode  1674 score 10.0 avg_score 20.8
# episode  1675 score 25.0 avg_score 20.7
# episode  1676 score 23.0 avg_score 20.8
# episode  1677 score 15.0 avg_score 20.8
# episode  1678 score 17.0 avg_score 20.8
# episode  1679 score 16.0 avg_score 20.7
# episode  1680 score 43.0 avg_score 21.0
# episode  1681 score 11.0 avg_score 20.9
# episode  1682 score 18.0 avg_score 21.0
# episode  1683 score 12.0 avg_score 20.4
# episode  1684 score 21.0 avg_score 20.5
# episode  1685 score 37.0 avg_score 20.5
# episode  1686 score 28.0 avg_score 20.6
# episode  1687 score 20.0 avg_score 20.7
# episode  1688 score 9.0 avg_score 20.6
# episode  1689 score 37.0 avg_score 20.9
# episode  1690 score 12.0 avg_score 20.9
# episode  1691 score 12.0 avg_score 20.8
# episode  1692 score 34.0 avg_score 21.0
# episode  1693 score 18.0 avg_score 21.1
# episode  1694 score 19.0 avg_score 20.9
# episode  1695 score 57.0 avg_score 21.0
# episode  1696 score 12.0 avg_score 21.0
# episode  1697 score 35.0 avg_score 21.1
# episode  1698 score 21.0 avg_score 21.1
# episode  1699 score 77.0 avg_score 21.8
# episode  1700 score 11.0 avg_score 21.7
# episode  1701 score 13.0 avg_score 21.4
# episode  1702 score 12.0 avg_score 21.4
# episode  1703 score 13.0 avg_score 21.4
# episode  1704 score 18.0 avg_score 21.5
# episode  1705 score 50.0 avg_score 21.8
# episode  1706 score 13.0 avg_score 21.8
# episode  1707 score 21.0 avg_score 21.7
# episode  1708 score 15.0 avg_score 21.7
# episode  1709 score 32.0 avg_score 21.8
# episode  1710 score 24.0 avg_score 22.0
# episode  1711 score 17.0 avg_score 22.0
# episode  1712 score 15.0 avg_score 22.0
# episode  1713 score 32.0 avg_score 21.9
# episode  1714 score 17.0 avg_score 21.9
# episode  1715 score 26.0 avg_score 21.9
# episode  1716 score 13.0 avg_score 21.8
# episode  1717 score 19.0 avg_score 21.7
# episode  1718 score 14.0 avg_score 21.7
# episode  1719 score 21.0 avg_score 21.7
# episode  1720 score 36.0 avg_score 21.9
# episode  1721 score 20.0 avg_score 21.7
# episode  1722 score 16.0 avg_score 21.6
# episode  1723 score 15.0 avg_score 21.7
# episode  1724 score 13.0 avg_score 21.7
# episode  1725 score 22.0 avg_score 21.6
# episode  1726 score 19.0 avg_score 21.6
# episode  1727 score 39.0 avg_score 21.8
# episode  1728 score 12.0 avg_score 21.8
# episode  1729 score 25.0 avg_score 21.7
# episode  1730 score 21.0 avg_score 21.8
# episode  1731 score 18.0 avg_score 21.6
# episode  1732 score 20.0 avg_score 21.8
# episode  1733 score 35.0 avg_score 21.8
# episode  1734 score 15.0 avg_score 21.5
# episode  1735 score 14.0 avg_score 21.4
# episode  1736 score 30.0 avg_score 21.3
# episode  1737 score 9.0 avg_score 21.1
# episode  1738 score 47.0 avg_score 21.4
# episode  1739 score 16.0 avg_score 21.4
# episode  1740 score 11.0 avg_score 21.3
# episode  1741 score 22.0 avg_score 21.4
# episode  1742 score 12.0 avg_score 21.2
# episode  1743 score 14.0 avg_score 21.2
# episode  1744 score 21.0 avg_score 21.3
# episode  1745 score 31.0 avg_score 21.5
# episode  1746 score 18.0 avg_score 21.4
# episode  1747 score 14.0 avg_score 21.3
# episode  1748 score 18.0 avg_score 21.2
# episode  1749 score 17.0 avg_score 21.3
# episode  1750 score 22.0 avg_score 21.2
# episode  1751 score 19.0 avg_score 21.4
# episode  1752 score 24.0 avg_score 21.4
# episode  1753 score 18.0 avg_score 21.3
# episode  1754 score 14.0 avg_score 21.3
# episode  1755 score 20.0 avg_score 21.4
# episode  1756 score 29.0 avg_score 21.4
# episode  1757 score 18.0 avg_score 21.3
# episode  1758 score 16.0 avg_score 21.3
# episode  1759 score 16.0 avg_score 21.3
# episode  1760 score 10.0 avg_score 21.2
# episode  1761 score 44.0 avg_score 21.5
# episode  1762 score 12.0 avg_score 21.5
# episode  1763 score 18.0 avg_score 21.5
# episode  1764 score 14.0 avg_score 21.4
# episode  1765 score 19.0 avg_score 21.1
# episode  1766 score 17.0 avg_score 21.2
# episode  1767 score 19.0 avg_score 21.3
# episode  1768 score 12.0 avg_score 21.1
# episode  1769 score 11.0 avg_score 21.0
# episode  1770 score 14.0 avg_score 21.0
# episode  1771 score 17.0 avg_score 21.0
# episode  1772 score 17.0 avg_score 21.0
# episode  1773 score 22.0 avg_score 21.0
# episode  1774 score 12.0 avg_score 21.0
# episode  1775 score 18.0 avg_score 20.9
# episode  1776 score 38.0 avg_score 21.1
# episode  1777 score 31.0 avg_score 21.2
# episode  1778 score 22.0 avg_score 21.3
# episode  1779 score 10.0 avg_score 21.2
# episode  1780 score 9.0 avg_score 20.9
# episode  1781 score 21.0 avg_score 21.0
# episode  1782 score 25.0 avg_score 21.1
# episode  1783 score 22.0 avg_score 21.1
# episode  1784 score 19.0 avg_score 21.1
# episode  1785 score 24.0 avg_score 21.0
# episode  1786 score 20.0 avg_score 20.9
# episode  1787 score 18.0 avg_score 20.9
# episode  1788 score 12.0 avg_score 20.9
# episode  1789 score 19.0 avg_score 20.8
# episode  1790 score 16.0 avg_score 20.8
# episode  1791 score 33.0 avg_score 21.0
# episode  1792 score 23.0 avg_score 20.9
# episode  1793 score 41.0 avg_score 21.1
# episode  1794 score 20.0 avg_score 21.1
# episode  1795 score 12.0 avg_score 20.7
# episode  1796 score 24.0 avg_score 20.8
# episode  1797 score 22.0 avg_score 20.7
# episode  1798 score 12.0 avg_score 20.6
# episode  1799 score 17.0 avg_score 20.0
