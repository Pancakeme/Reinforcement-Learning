# %%
import numpy as np
import os
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import gym
import matplotlib.pyplot as plt

# %%
class ReplayBuffer:
  def __init__(self, max_size, input_shape, n_actions):
    self.mem_size = max_size
    self.mem_cntr = 0
    self.state_memory = np.zeros((self.mem_size, *input_shape))
    self.new_state_memory = np.zeros((self.mem_size, *input_shape))
    self.action_memory = np.zeros((self.mem_size, n_actions))
    self.reward_memory = np.zeros(self.mem_size)
    self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

  def store_transition(self, state, action, reward, new_state, done):
    index = self.mem_cntr %self.mem_size

    self.state_memory[index] = state
    self.new_state_memory[index] = new_state
    self.action_memory[index] = action
    self.reward_memory[index] = reward
    self.terminal_memory[index] = done

    self.mem_cntr += 1

  def sample_buffer(self, batch_size):
    max_mem = min(self.mem_cntr, self.mem_size)

    batch = np.random.choice(max_mem, batch_size, replace = False)

    states = self.state_memory[batch]
    states_ = self.new_state_memory[batch]
    actions = self.action_memory[batch]
    rewards = self.reward_memory[batch]
    dones = self.terminal_memory[batch]

    return states, actions, rewards, states_, dones

# %%
class CriticNetwork(keras.Model):
  def __init__(self, fc1_dims = 512, fc2_dims = 512, name ='critic', chkpt_dir = '/content/all'):
    super(CriticNetwork, self).__init__()
    self.fc1_dims = fc1_dims
    self.fc2_dims = fc2_dims

    self.model_name = name
    self.checkpoint_dir = chkpt_dir
    self.checkpoint_file = os.path.join(self.checkpoint_dir, self.model_name+'ddpg.h5')

    self.fc1 = Dense(self.fc1_dims, activation='relu')
    self.fc2 = Dense(self.fc2_dims, activation = 'relu')
    self.q = Dense(1, activation=None)

  def call(self, state, action):
    action_value = self.fc1(tf.concat([state, action], axis=1))
    action_value = self.fc2(action_value)

    q = self.q(action_value)

    return q

class ActorNetwork(keras.Model):
  def __init__(self, fc1_dims=512, fc2_dims=512, n_actions=2, name='actor', chkpt_dir = '/content/all'):
    super(ActorNetwork, self).__init__()
    self.fc1_dims = fc1_dims
    self.fc2_dims = fc2_dims
    self.n_actions = n_actions

    self.model_name = name
    self.checkpoint_dir = chkpt_dir
    self.checkpoint_file = os.path.join(self.checkpoint_dir, self.model_name+'ddpg.h5')

    self.fc1 = Dense(self.fc1_dims, activation='relu')
    self.fc2 = Dense(self.fc2_dims, activation='relu')
    self.mu = Dense(self.n_actions, activation='tanh')

  def call(self, state):
    prob = self.fc1(state)
    prob = self.fc2(prob)

    mu = self.mu(prob)

    return mu

# %%
class Agent:
  def __init__(self, input_dims, alpha=0.001, beta=0.002, env=None, gamma = 0.99, n_actions=2, max_size=1000000, tau=0.005, fc1=400, fc2=300, batch_size=64, noise=0.1):
    self.gamma = gamma
    self.tau = tau
    self.memory = ReplayBuffer(max_size, input_dims, n_actions)
    self.batch_size = batch_size
    self.n_actions = n_actions
    self.noise = noise
    self.max_action = env.action_space.high[0]
    self.min_action = env.action_space.low[0]

    self.actor = ActorNetwork(n_actions=n_actions, name='actor')
    self.critic = CriticNetwork(name='critic')
    self.target_actor = ActorNetwork(n_actions=n_actions, name='target_actor')
    self.target_critic = CriticNetwork(name='target_critic')

    self.actor.compile(optimizer=Adam(learning_rate=alpha))
    self.critic.compile(optimizer=Adam(learning_rate=beta))
    self.target_actor.compile(optimizer=Adam(learning_rate=alpha))
    self.target_critic.compile(optimizer=Adam(learning_rate=beta))

    self.update_network_parameters(tau=1)

  def update_network_parameters(self, tau=None):
    if tau is None:
      tau=self.tau
    weights = []
    targets = self.target_actor.weights
    for i, weight in enumerate(self.actor.weights):
      weights.append(weight*tau + targets[i]*(1-tau))
    self.target_actor.set_weights(weights)

    weights = []
    targets = self.target_critic.weights
    for i, weight in enumerate(self.critic.weights):
      weights.append(weight*tau + targets[i]*(1-tau))
    self.target_critic.set_weights(weights)

  def remember(self, state, action, reward, new_state, done):
    self.memory.store_transition(state, action, reward, new_state, done)

  def save_models(self):
    print('....saving models.....')
    self.actor.save_weights(self.actor.checkpoint_file)
    self.critic.save_weights(self.critic.checkpoint_file)
    self.target_actor.save_weights(self.target_actor.checkpoint_file)
    self.target_critic.save_weights(self.target_critic.checkpoint_file)

  def load_models(self):
    print('.....loading models....')
    self.actor.load_weights(self.actor.checkpoint_file)
    self.critic.load_weights(self.critic.checkpoint_file)
    self.target_actor.load_weights(self.target_actor.checkpoint_file)
    self.target_critic.load_weights(self.target_critic.checkpoint_file)

  def choose_action(self, observation, evaluate=False):
    state = tf.convert_to_tensor([observation], dtype=tf.float32)
    actions = self.actor(state)
    if not evaluate:
      actions += tf.random.normal(shape=[self.n_actions], mean=0.0, stddev=self.noise)
    actions = tf.clip_by_value(actions, self.min_action, self.max_action)

    return actions[0]

  def learn(self):
    if self.memory.mem_cntr < self.batch_size:
      return

    state, action, reward, new_state, done = self.memory.sample_buffer(self.batch_size)

    states = tf.convert_to_tensor(state, dtype=tf.float32)
    states_ = tf.convert_to_tensor(new_state, dtype=tf.float32)
    actions = tf.convert_to_tensor(action, dtype=tf.float32)
    rewards = tf.convert_to_tensor(reward, dtype=tf.float32)

    with tf.GradientTape() as tape:
      target_actions = self.target_actor(states_)
      critic_value_ = tf.squeeze(self.target_critic(states_, target_actions), 1)
      critic_value = tf.squeeze(self.critic(states, actions), 1)
      target = reward + self.gamma*critic_value_*(1-done)
      critic_loss = keras.losses.MSE(target, critic_value)

    critic_network_gradient = tape.gradient(critic_loss, self.critic.trainable_variables)
    self.critic.optimizer.apply_gradients(zip(critic_network_gradient, self.critic.trainable_variables))

    with tf.GradientTape() as tape:
      new_policy_actions = self.actor(states)
      actor_loss = -self.critic(states, new_policy_actions)
      actor_loss = tf.math.reduce_mean(actor_loss)

    actor_network_gradient = tape.gradient(actor_loss, self.actor.trainable_variables)
    self.actor.optimizer.apply_gradients(zip(actor_network_gradient, self.actor.trainable_variables))

    self.update_network_parameters()

# %%
if __name__ == '__main__':
  env = gym.make('Pendulum-v1')
  agent = Agent(input_dims=env.observation_space.shape, env=env, n_actions=env.action_space.shape[0])
  n_games = 250

  best_score = env.reward_range[0]
  score_history = []
  load_checkpoint = False

  if load_checkpoint:
    n_steps = 0
    while n_steps <= agent.batch_size:
      observation = env.reset()
      action = env.action_space.sample()
      observation_, reward, done, info = env.step(action)
      agent.remember(observation, action, reward, observation_, done)
      n_steps +=1
    agent.learn()
    agent.load_models()
    evaluate = True
  else:
    evaluate = False

  for i in range(n_games):
    observation = env.reset()
    done = False
    score = 0
    while not done:
      action = agent.choose_action(observation, evaluate)
      observation_, reward, done, info = env.step(action)
      score += reward
      agent.remember(observation, action, reward, observation_, done)
      if not load_checkpoint:
        agent.learn()
      observation = observation_
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])

    if avg_score > best_score:
      best_score = avg_score
      if not load_checkpoint:
        agent.save_models()
    print('episode ', i, 'score %.1f' % score, 'avg_score %.1f' %avg_score)

  if not load_checkpoint:
    x = [i+1 for i in range(n_games)]
    plt.plot(x, score_history)
# Out:
# <ipython-input-8-2109498db5f1>:9: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)
# ....saving models.....
# episode  0 score -1270.0 avg_score -1270.0
# ....saving models.....
# episode  1 score -1059.8 avg_score -1164.9
# episode  2 score -1789.7 avg_score -1373.2
# episode  3 score -1430.8 avg_score -1387.6
# episode  4 score -1465.4 avg_score -1403.1
# episode  5 score -1396.1 avg_score -1402.0
# episode  6 score -1356.2 avg_score -1395.4
# episode  7 score -1257.6 avg_score -1378.2
# episode  8 score -1136.6 avg_score -1351.4
# episode  9 score -1334.0 avg_score -1349.6
# episode  10 score -1303.5 avg_score -1345.4
# episode  11 score -990.8 avg_score -1315.9
# episode  12 score -826.9 avg_score -1278.3
# episode  13 score -1189.5 avg_score -1271.9
# episode  14 score -1191.1 avg_score -1266.5
# episode  15 score -126.8 avg_score -1195.3
# episode  16 score -1144.9 avg_score -1192.3
# ....saving models.....
# episode  17 score -243.5 avg_score -1139.6
# ....saving models.....
# episode  18 score -127.4 avg_score -1086.3
# ....saving models.....
# episode  19 score -126.0 avg_score -1038.3
# ....saving models.....
# episode  20 score -366.7 avg_score -1006.3
# ....saving models.....
# episode  21 score -649.6 avg_score -990.1
# ....saving models.....
# episode  22 score -602.8 avg_score -973.3
# ....saving models.....
# episode  23 score -122.2 avg_score -937.8
# ....saving models.....
# episode  24 score -507.4 avg_score -920.6
# ....saving models.....
# episode  25 score -375.3 avg_score -899.6
# ....saving models.....
# episode  26 score -120.7 avg_score -870.8
# ....saving models.....
# episode  27 score -357.4 avg_score -852.5
# ....saving models.....
# episode  28 score -701.8 avg_score -847.3
# ....saving models.....
# episode  29 score -492.6 avg_score -835.4
# ....saving models.....
# episode  30 score -119.8 avg_score -812.4
# ....saving models.....
# episode  31 score -366.0 avg_score -798.4
# ....saving models.....
# episode  32 score -127.0 avg_score -778.1
# ....saving models.....
# episode  33 score -124.2 avg_score -758.8
# ....saving models.....
# episode  34 score -241.3 avg_score -744.0
# ....saving models.....
# episode  35 score -484.7 avg_score -736.8
# ....saving models.....
# episode  36 score -373.2 avg_score -727.0
# ....saving models.....
# episode  37 score -125.3 avg_score -711.2
# ....saving models.....
# episode  38 score -122.9 avg_score -696.1
# ....saving models.....
# episode  39 score -253.1 avg_score -685.0
# ....saving models.....
# episode  40 score -241.0 avg_score -674.2
# ....saving models.....
# episode  41 score -126.1 avg_score -661.1
# ....saving models.....
# episode  42 score -126.4 avg_score -648.7
# ....saving models.....
# episode  43 score -119.2 avg_score -636.7
# ....saving models.....
# episode  44 score -122.4 avg_score -625.2
# ....saving models.....
# episode  45 score -119.6 avg_score -614.2
# ....saving models.....
# episode  46 score -122.2 avg_score -603.8
# ....saving models.....
# episode  47 score -242.7 avg_score -596.3
# ....saving models.....
# episode  48 score -0.3 avg_score -584.1
# ....saving models.....
# episode  49 score -122.3 avg_score -574.9
# ....saving models.....
# episode  50 score -518.0 avg_score -573.7
# ....saving models.....
# episode  51 score -120.8 avg_score -565.0
# ....saving models.....
# episode  52 score -490.7 avg_score -563.6
# episode  53 score -627.5 avg_score -564.8
# episode  54 score -516.5 avg_score -563.9
# ....saving models.....
# episode  55 score -0.5 avg_score -553.9
# ....saving models.....
# episode  56 score -0.4 avg_score -544.2
# ....saving models.....
# episode  57 score -234.8 avg_score -538.8
# ....saving models.....
# episode  58 score -124.9 avg_score -531.8
# ....saving models.....
# episode  59 score -241.5 avg_score -527.0
# ....saving models.....
# episode  60 score -124.2 avg_score -520.4
# ....saving models.....
# episode  61 score -0.5 avg_score -512.0
# episode  62 score -609.8 avg_score -513.5
# ....saving models.....
# episode  63 score -356.4 avg_score -511.1
# ....saving models.....
# episode  64 score -123.5 avg_score -505.1
# ....saving models.....
# episode  65 score -126.7 avg_score -499.4
# ....saving models.....
# episode  66 score -121.1 avg_score -493.7
# ....saving models.....
# episode  67 score -124.6 avg_score -488.3
# ....saving models.....
# episode  68 score -121.7 avg_score -483.0
# ....saving models.....
# episode  69 score -357.7 avg_score -481.2
# ....saving models.....
# episode  70 score -0.2 avg_score -474.4
# ....saving models.....
# episode  71 score -120.6 avg_score -469.5
# ....saving models.....
# episode  72 score -353.1 avg_score -467.9
# ....saving models.....
# episode  73 score -123.1 avg_score -463.3
# ....saving models.....
# episode  74 score -366.9 avg_score -462.0
# ....saving models.....
# episode  75 score -124.6 avg_score -457.5
# ....saving models.....
# episode  76 score -123.9 avg_score -453.2
# ....saving models.....
# episode  77 score -240.0 avg_score -450.5
# ....saving models.....
# episode  78 score -121.6 avg_score -446.3
# ....saving models.....
# episode  79 score -235.4 avg_score -443.7
# ....saving models.....
# episode  80 score -237.9 avg_score -441.1
# episode  81 score -498.3 avg_score -441.8
# ....saving models.....
# episode  82 score -124.2 avg_score -438.0
# ....saving models.....
# episode  83 score -355.9 avg_score -437.0
# ....saving models.....
# episode  84 score -376.7 avg_score -436.3
# episode  85 score -482.7 avg_score -436.9
# ....saving models.....
# episode  86 score -1.3 avg_score -431.8
# episode  87 score -473.0 avg_score -432.3
# ....saving models.....
# episode  88 score -123.8 avg_score -428.8
# ....saving models.....
# episode  89 score -122.2 avg_score -425.4
# episode  90 score -499.8 avg_score -426.3
# episode  91 score -359.1 avg_score -425.5
# episode  92 score -483.8 avg_score -426.2
# ....saving models.....
# episode  93 score -1.1 avg_score -421.6
# ....saving models.....
# episode  94 score -237.8 avg_score -419.7
# episode  95 score -486.0 avg_score -420.4
# episode  96 score -362.7 avg_score -419.8
# ....saving models.....
# episode  97 score -362.8 avg_score -419.2
# ....saving models.....
# episode  98 score -121.1 avg_score -416.2
# ....saving models.....
# episode  99 score -121.3 avg_score -413.3
# ....saving models.....
# episode  100 score -1.1 avg_score -400.6
# ....saving models.....
# episode  101 score -239.8 avg_score -392.4
# ....saving models.....
# episode  102 score -509.0 avg_score -379.6
# ....saving models.....
# episode  103 score -242.9 avg_score -367.7
# ....saving models.....
# episode  104 score -125.1 avg_score -354.3
# ....saving models.....
# episode  105 score -122.2 avg_score -341.5
# ....saving models.....
# episode  106 score -525.0 avg_score -333.2
# ....saving models.....
# episode  107 score -367.6 avg_score -324.3
# ....saving models.....
# episode  108 score -236.1 avg_score -315.3
# ....saving models.....
# episode  109 score -121.8 avg_score -303.2
# ....saving models.....
# episode  110 score -124.7 avg_score -291.4
# ....saving models.....
# episode  111 score -125.4 avg_score -282.8
# ....saving models.....
# episode  112 score -633.5 avg_score -280.8
# ....saving models.....
# episode  113 score -606.6 avg_score -275.0
# ....saving models.....
# episode  114 score -580.4 avg_score -268.9
# episode  115 score -356.4 avg_score -271.2
# ....saving models.....
# episode  116 score -488.4 avg_score -264.6
# ....saving models.....
# episode  117 score -0.5 avg_score -262.2
# episode  118 score -235.2 avg_score -263.3
# episode  119 score -121.6 avg_score -263.2
# episode  120 score -357.4 avg_score -263.1
# ....saving models.....
# episode  121 score -235.9 avg_score -259.0
# ....saving models.....
# episode  122 score -516.6 avg_score -258.1
# episode  123 score -516.5 avg_score -262.1
# episode  124 score -237.7 avg_score -259.4
# ....saving models.....
# episode  125 score -123.1 avg_score -256.9
# episode  126 score -361.3 avg_score -259.3
# episode  127 score -120.4 avg_score -256.9
# ....saving models.....
# episode  128 score -125.6 avg_score -251.1
# episode  129 score -549.7 avg_score -251.7
# episode  130 score -122.6 avg_score -251.7
# ....saving models.....
# episode  131 score -124.3 avg_score -249.3
# episode  132 score -495.4 avg_score -253.0
# episode  133 score -121.8 avg_score -253.0
# episode  134 score -122.1 avg_score -251.8
# episode  135 score -627.7 avg_score -253.2
# episode  136 score -124.8 avg_score -250.7
# episode  137 score -126.1 avg_score -250.7
# episode  138 score -234.5 avg_score -251.8
# episode  139 score -126.7 avg_score -250.6
# ....saving models.....
# episode  140 score -1.6 avg_score -248.2
# ....saving models.....
# episode  141 score -121.8 avg_score -248.1
# ....saving models.....
# episode  142 score -117.7 avg_score -248.1
# episode  143 score -126.2 avg_score -248.1
# episode  144 score -676.2 avg_score -253.7
# episode  145 score -124.4 avg_score -253.7
# episode  146 score -241.1 avg_score -254.9
# episode  147 score -123.1 avg_score -253.7
# episode  148 score -122.0 avg_score -254.9
# episode  149 score -126.5 avg_score -255.0
# episode  150 score -0.4 avg_score -249.8
# episode  151 score -122.5 avg_score -249.8
# ....saving models.....
# episode  152 score -234.7 avg_score -247.2
# ....saving models.....
# episode  153 score -126.0 avg_score -242.2
# ....saving models.....
# episode  154 score -240.5 avg_score -239.5
# episode  155 score -119.1 avg_score -240.7
# episode  156 score -497.4 avg_score -245.6
# episode  157 score -125.7 avg_score -244.5
# episode  158 score -123.7 avg_score -244.5
